# %%
# 训练五子棋AI

from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque

# %%
import os
# 硬盘授权
from google.colab import drive
drive.mount('/content/drive/')

# 设置路径
import os
path = '/content/drive/My Drive/Colab Notebooks'
os.chdir(path)

from game import Game,Board
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphazero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch
# Out:
# Mounted at /content/drive/

# %%
class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 6
        self.board_height = 6
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
    # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /content/drive/My Drive/Colab Notebooks/policy_value_net_pytorch.py:53: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:12
# batch i:2, episode_len:15
# batch i:3, episode_len:17
# batch i:4, episode_len:22
# kl:0.00110,lr_multiplier:1.500,loss:4.555370330810547,entropy:3.582127571105957,explained_var_old:-0.000,explained_var_new:0.039
# batch i:5, episode_len:15
# kl:0.00887,lr_multiplier:2.250,loss:4.319193363189697,entropy:3.5636091232299805,explained_var_old:0.032,explained_var_new:0.344
# batch i:6, episode_len:18
# kl:0.00660,lr_multiplier:3.375,loss:4.287353038787842,entropy:3.5537667274475098,explained_var_old:0.155,explained_var_new:0.298
# batch i:7, episode_len:12
# kl:0.00951,lr_multiplier:5.062,loss:4.082947731018066,entropy:3.5460703372955322,explained_var_old:0.330,explained_var_new:0.481
# batch i:8, episode_len:9
# kl:0.07453,lr_multiplier:3.375,loss:3.951880693435669,entropy:3.511732339859009,explained_var_old:0.408,explained_var_new:0.536
# batch i:9, episode_len:16
# kl:0.05990,lr_multiplier:2.250,loss:4.267404079437256,entropy:3.530409574508667,explained_var_old:0.145,explained_var_new:0.250
# batch i:10, episode_len:16
# kl:0.02185,lr_multiplier:2.250,loss:4.291025161743164,entropy:3.4910058975219727,explained_var_old:0.028,explained_var_new:0.235
# batch i:11, episode_len:21
# kl:0.01707,lr_multiplier:2.250,loss:4.233227729797363,entropy:3.4908463954925537,explained_var_old:0.101,explained_var_new:0.271
# batch i:12, episode_len:12
# kl:0.02869,lr_multiplier:2.250,loss:4.087435722351074,entropy:3.4491209983825684,explained_var_old:0.235,explained_var_new:0.411
# batch i:13, episode_len:13
# kl:0.02352,lr_multiplier:2.250,loss:4.068972587585449,entropy:3.470454454421997,explained_var_old:0.254,explained_var_new:0.390
# batch i:14, episode_len:12
# kl:0.02666,lr_multiplier:2.250,loss:3.9402263164520264,entropy:3.4008212089538574,explained_var_old:0.355,explained_var_new:0.490
# batch i:15, episode_len:20
# kl:0.02673,lr_multiplier:2.250,loss:3.8294074535369873,entropy:3.38258695602417,explained_var_old:0.398,explained_var_new:0.565
# batch i:16, episode_len:14
# kl:0.05456,lr_multiplier:1.500,loss:3.7100796699523926,entropy:3.3775579929351807,explained_var_old:0.463,explained_var_new:0.644
# batch i:17, episode_len:18
# kl:0.03452,lr_multiplier:1.500,loss:3.7555198669433594,entropy:3.3605074882507324,explained_var_old:0.444,explained_var_new:0.595
# batch i:18, episode_len:16
# kl:0.04363,lr_multiplier:1.000,loss:3.6036136150360107,entropy:3.268254041671753,explained_var_old:0.581,explained_var_new:0.714
# batch i:19, episode_len:22
# kl:0.02159,lr_multiplier:1.000,loss:3.59456729888916,entropy:3.3103132247924805,explained_var_old:0.619,explained_var_new:0.693
# batch i:20, episode_len:17
# kl:0.01793,lr_multiplier:1.000,loss:3.6431260108947754,entropy:3.292750835418701,explained_var_old:0.544,explained_var_new:0.664
# batch i:21, episode_len:12
# kl:0.02181,lr_multiplier:1.000,loss:3.6158535480499268,entropy:3.2556557655334473,explained_var_old:0.560,explained_var_new:0.650
# batch i:22, episode_len:14
# kl:0.02707,lr_multiplier:1.000,loss:3.517490863800049,entropy:3.2535128593444824,explained_var_old:0.637,explained_var_new:0.724
# batch i:23, episode_len:13
# kl:0.02802,lr_multiplier:1.000,loss:3.511798858642578,entropy:3.195709466934204,explained_var_old:0.578,explained_var_new:0.679
# batch i:24, episode_len:9
# kl:0.03832,lr_multiplier:1.000,loss:3.541029930114746,entropy:3.195266008377075,explained_var_old:0.532,explained_var_new:0.662
# batch i:25, episode_len:24
# kl:0.03544,lr_multiplier:1.000,loss:3.546578884124756,entropy:3.178342342376709,explained_var_old:0.504,explained_var_new:0.660
# batch i:26, episode_len:10
# kl:0.03586,lr_multiplier:1.000,loss:3.4864070415496826,entropy:3.19867205619812,explained_var_old:0.590,explained_var_new:0.698
# batch i:27, episode_len:20
# kl:0.03278,lr_multiplier:1.000,loss:3.450925350189209,entropy:3.1835079193115234,explained_var_old:0.611,explained_var_new:0.727
# batch i:28, episode_len:15
# kl:0.03090,lr_multiplier:1.000,loss:3.5280210971832275,entropy:3.1690878868103027,explained_var_old:0.533,explained_var_new:0.658
# batch i:29, episode_len:13
# kl:0.03608,lr_multiplier:1.000,loss:3.3775298595428467,entropy:3.0648155212402344,explained_var_old:0.541,explained_var_new:0.698
# batch i:30, episode_len:19
# kl:0.04420,lr_multiplier:0.667,loss:3.597292184829712,entropy:3.148050308227539,explained_var_old:0.409,explained_var_new:0.537
# batch i:31, episode_len:10
# kl:0.02146,lr_multiplier:0.667,loss:3.535900592803955,entropy:3.1117186546325684,explained_var_old:0.417,explained_var_new:0.573
# batch i:32, episode_len:18
# kl:0.02186,lr_multiplier:0.667,loss:3.5238442420959473,entropy:3.1046509742736816,explained_var_old:0.460,explained_var_new:0.579
# batch i:33, episode_len:17
# kl:0.01740,lr_multiplier:0.667,loss:3.5527992248535156,entropy:3.099897861480713,explained_var_old:0.405,explained_var_new:0.530
# batch i:34, episode_len:17
# kl:0.01953,lr_multiplier:0.667,loss:3.5559282302856445,entropy:3.119548797607422,explained_var_old:0.425,explained_var_new:0.562
# batch i:35, episode_len:10
# kl:0.02662,lr_multiplier:0.667,loss:3.5656676292419434,entropy:3.119676113128662,explained_var_old:0.462,explained_var_new:0.547
# batch i:36, episode_len:14
# kl:0.02780,lr_multiplier:0.667,loss:3.492079734802246,entropy:3.0653207302093506,explained_var_old:0.474,explained_var_new:0.596
# batch i:37, episode_len:10
# kl:0.02455,lr_multiplier:0.667,loss:3.4131925106048584,entropy:3.0140137672424316,explained_var_old:0.489,explained_var_new:0.622
# batch i:38, episode_len:14
# kl:0.02830,lr_multiplier:0.667,loss:3.4033806324005127,entropy:3.058769702911377,explained_var_old:0.525,explained_var_new:0.659
# batch i:39, episode_len:14
# kl:0.03462,lr_multiplier:0.667,loss:3.4119319915771484,entropy:3.0447940826416016,explained_var_old:0.562,explained_var_new:0.662
# batch i:40, episode_len:8
# kl:0.02471,lr_multiplier:0.667,loss:3.417926788330078,entropy:3.0850396156311035,explained_var_old:0.524,explained_var_new:0.639
# batch i:41, episode_len:17
# kl:0.01984,lr_multiplier:0.667,loss:3.402540445327759,entropy:3.0742454528808594,explained_var_old:0.585,explained_var_new:0.666
# batch i:42, episode_len:18
# kl:0.03408,lr_multiplier:0.667,loss:3.388727903366089,entropy:2.983468770980835,explained_var_old:0.488,explained_var_new:0.615
# batch i:43, episode_len:16
# kl:0.03637,lr_multiplier:0.667,loss:3.3388350009918213,entropy:2.998843193054199,explained_var_old:0.553,explained_var_new:0.688
# batch i:44, episode_len:12
# kl:0.02637,lr_multiplier:0.667,loss:3.2952606678009033,entropy:3.001746416091919,explained_var_old:0.635,explained_var_new:0.722
# batch i:45, episode_len:10
# kl:0.02828,lr_multiplier:0.667,loss:3.361121892929077,entropy:3.058894634246826,explained_var_old:0.539,explained_var_new:0.642
# batch i:46, episode_len:10
# kl:0.02770,lr_multiplier:0.667,loss:3.3326704502105713,entropy:2.996675491333008,explained_var_old:0.576,explained_var_new:0.684
# batch i:47, episode_len:10
# kl:0.02147,lr_multiplier:0.667,loss:3.2700657844543457,entropy:3.051513433456421,explained_var_old:0.670,explained_var_new:0.748
# batch i:48, episode_len:13
# kl:0.02916,lr_multiplier:0.667,loss:3.2642078399658203,entropy:3.014946937561035,explained_var_old:0.627,explained_var_new:0.751
# batch i:49, episode_len:12
# kl:0.02938,lr_multiplier:0.667,loss:3.297557830810547,entropy:3.008173704147339,explained_var_old:0.595,explained_var_new:0.700
# batch i:50, episode_len:14
# kl:0.02263,lr_multiplier:0.667,loss:3.319206714630127,entropy:2.993039846420288,explained_var_old:0.610,explained_var_new:0.695
# current self-play batch: 50
# num_playouts:1000, win: 1, lose: 9, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:15
# kl:0.02782,lr_multiplier:0.667,loss:3.339938163757324,entropy:3.0217649936676025,explained_var_old:0.557,explained_var_new:0.667
# batch i:52, episode_len:13
# kl:0.02270,lr_multiplier:0.667,loss:3.3908371925354004,entropy:3.0194990634918213,explained_var_old:0.516,explained_var_new:0.620
# batch i:53, episode_len:9
# kl:0.02043,lr_multiplier:0.667,loss:3.314175605773926,entropy:2.941697359085083,explained_var_old:0.470,explained_var_new:0.609
# batch i:54, episode_len:13
# kl:0.03150,lr_multiplier:0.667,loss:3.3703880310058594,entropy:2.9741923809051514,explained_var_old:0.499,explained_var_new:0.626
# batch i:55, episode_len:13
# kl:0.02469,lr_multiplier:0.667,loss:3.3188555240631104,entropy:2.951639175415039,explained_var_old:0.474,explained_var_new:0.596
# batch i:56, episode_len:7
# kl:0.04825,lr_multiplier:0.444,loss:3.392918586730957,entropy:2.9642813205718994,explained_var_old:0.433,explained_var_new:0.571
# batch i:57, episode_len:12
# kl:0.02176,lr_multiplier:0.444,loss:3.429076910018921,entropy:2.952733039855957,explained_var_old:0.418,explained_var_new:0.539
# batch i:58, episode_len:12
# kl:0.01885,lr_multiplier:0.444,loss:3.479053020477295,entropy:2.9834344387054443,explained_var_old:0.463,explained_var_new:0.540
# batch i:59, episode_len:11
# kl:0.02061,lr_multiplier:0.444,loss:3.3835277557373047,entropy:2.9598817825317383,explained_var_old:0.487,explained_var_new:0.581
# batch i:60, episode_len:16
# kl:0.01922,lr_multiplier:0.444,loss:3.349898338317871,entropy:2.978039264678955,explained_var_old:0.512,explained_var_new:0.602
# batch i:61, episode_len:13
# kl:0.01328,lr_multiplier:0.444,loss:3.4279370307922363,entropy:2.989163398742676,explained_var_old:0.460,explained_var_new:0.552
# batch i:62, episode_len:10
# kl:0.02119,lr_multiplier:0.444,loss:3.3283743858337402,entropy:2.9116969108581543,explained_var_old:0.503,explained_var_new:0.585
# batch i:63, episode_len:11
# kl:0.02421,lr_multiplier:0.444,loss:3.4895455837249756,entropy:2.999556303024292,explained_var_old:0.421,explained_var_new:0.512
# batch i:64, episode_len:13
# kl:0.01492,lr_multiplier:0.444,loss:3.521030902862549,entropy:3.0026557445526123,explained_var_old:0.343,explained_var_new:0.467
# batch i:65, episode_len:12
# kl:0.01437,lr_multiplier:0.444,loss:3.4643917083740234,entropy:2.9548001289367676,explained_var_old:0.443,explained_var_new:0.512
# batch i:66, episode_len:11
# kl:0.01404,lr_multiplier:0.444,loss:3.4720592498779297,entropy:2.9792442321777344,explained_var_old:0.406,explained_var_new:0.499
# batch i:67, episode_len:16
# kl:0.02157,lr_multiplier:0.444,loss:3.3774683475494385,entropy:2.9434220790863037,explained_var_old:0.458,explained_var_new:0.549
# batch i:68, episode_len:14
# kl:0.02489,lr_multiplier:0.444,loss:3.4307761192321777,entropy:2.9473798274993896,explained_var_old:0.420,explained_var_new:0.503
# batch i:69, episode_len:12
# kl:0.02333,lr_multiplier:0.444,loss:3.331387758255005,entropy:2.8624587059020996,explained_var_old:0.476,explained_var_new:0.559
# batch i:70, episode_len:13
# kl:0.02433,lr_multiplier:0.444,loss:3.412475824356079,entropy:2.881415605545044,explained_var_old:0.386,explained_var_new:0.465
# batch i:71, episode_len:14
# kl:0.02893,lr_multiplier:0.444,loss:3.3372855186462402,entropy:2.8754968643188477,explained_var_old:0.469,explained_var_new:0.558
# batch i:72, episode_len:12
# kl:0.01120,lr_multiplier:0.444,loss:3.441626787185669,entropy:2.8954834938049316,explained_var_old:0.387,explained_var_new:0.474
# batch i:73, episode_len:10
# kl:0.01605,lr_multiplier:0.444,loss:3.350522518157959,entropy:2.9322595596313477,explained_var_old:0.494,explained_var_new:0.589
# batch i:74, episode_len:16
# kl:0.01720,lr_multiplier:0.444,loss:3.3991260528564453,entropy:2.9324240684509277,explained_var_old:0.431,explained_var_new:0.536
# batch i:75, episode_len:10
# kl:0.02790,lr_multiplier:0.444,loss:3.3545355796813965,entropy:2.913747549057007,explained_var_old:0.466,explained_var_new:0.574
# batch i:76, episode_len:14
# kl:0.04133,lr_multiplier:0.296,loss:3.4142980575561523,entropy:2.9490270614624023,explained_var_old:0.436,explained_var_new:0.529
# batch i:77, episode_len:11
# kl:0.02782,lr_multiplier:0.296,loss:3.3718411922454834,entropy:2.8994855880737305,explained_var_old:0.402,explained_var_new:0.523
# batch i:78, episode_len:14
# kl:0.02764,lr_multiplier:0.296,loss:3.3956971168518066,entropy:2.9647345542907715,explained_var_old:0.463,explained_var_new:0.529
# batch i:79, episode_len:10
# kl:0.02762,lr_multiplier:0.296,loss:3.246530532836914,entropy:2.827632427215576,explained_var_old:0.509,explained_var_new:0.573
# batch i:80, episode_len:21
# kl:0.03575,lr_multiplier:0.296,loss:3.402071237564087,entropy:2.9358644485473633,explained_var_old:0.405,explained_var_new:0.493
# batch i:81, episode_len:14
# kl:0.03339,lr_multiplier:0.296,loss:3.310701608657837,entropy:2.751063108444214,explained_var_old:0.424,explained_var_new:0.481
# batch i:82, episode_len:12
# kl:0.02167,lr_multiplier:0.296,loss:3.382546901702881,entropy:2.884183645248413,explained_var_old:0.408,explained_var_new:0.475
# batch i:83, episode_len:16
# kl:0.01595,lr_multiplier:0.296,loss:3.396857261657715,entropy:2.858509063720703,explained_var_old:0.422,explained_var_new:0.512
# batch i:84, episode_len:15
# kl:0.00858,lr_multiplier:0.444,loss:3.393582820892334,entropy:2.898803234100342,explained_var_old:0.439,explained_var_new:0.486
# batch i:85, episode_len:12
# kl:0.01833,lr_multiplier:0.444,loss:3.411154270172119,entropy:2.8913955688476562,explained_var_old:0.393,explained_var_new:0.478
# batch i:86, episode_len:13
# kl:0.00930,lr_multiplier:0.667,loss:3.4150657653808594,entropy:2.856172561645508,explained_var_old:0.332,explained_var_new:0.443
# batch i:87, episode_len:13
# kl:0.02344,lr_multiplier:0.667,loss:3.4304590225219727,entropy:2.8644402027130127,explained_var_old:0.357,explained_var_new:0.450
# batch i:88, episode_len:12
# kl:0.02480,lr_multiplier:0.667,loss:3.376863956451416,entropy:2.8510961532592773,explained_var_old:0.354,explained_var_new:0.453
# batch i:89, episode_len:7
# kl:0.02846,lr_multiplier:0.667,loss:3.4414310455322266,entropy:2.8936519622802734,explained_var_old:0.355,explained_var_new:0.478
# batch i:90, episode_len:11
# kl:0.02173,lr_multiplier:0.667,loss:3.323448657989502,entropy:2.8122763633728027,explained_var_old:0.354,explained_var_new:0.480
# batch i:91, episode_len:11
# kl:0.02679,lr_multiplier:0.667,loss:3.3489537239074707,entropy:2.796384572982788,explained_var_old:0.363,explained_var_new:0.463
# batch i:92, episode_len:15
# kl:0.01702,lr_multiplier:0.667,loss:3.416694164276123,entropy:2.8340535163879395,explained_var_old:0.271,explained_var_new:0.442
# batch i:93, episode_len:10
# kl:0.04045,lr_multiplier:0.444,loss:3.3415234088897705,entropy:2.8249564170837402,explained_var_old:0.348,explained_var_new:0.473
# batch i:94, episode_len:16
# kl:0.01427,lr_multiplier:0.444,loss:3.317837715148926,entropy:2.7790160179138184,explained_var_old:0.371,explained_var_new:0.452
# batch i:95, episode_len:11
# kl:0.01707,lr_multiplier:0.444,loss:3.2620534896850586,entropy:2.7347912788391113,explained_var_old:0.342,explained_var_new:0.446
# batch i:96, episode_len:13
# kl:0.01941,lr_multiplier:0.444,loss:3.3551230430603027,entropy:2.7896852493286133,explained_var_old:0.372,explained_var_new:0.432
# batch i:97, episode_len:10
# kl:0.02548,lr_multiplier:0.444,loss:3.279451608657837,entropy:2.7686758041381836,explained_var_old:0.410,explained_var_new:0.501
# batch i:98, episode_len:8
# kl:0.03036,lr_multiplier:0.444,loss:3.238215684890747,entropy:2.7096314430236816,explained_var_old:0.439,explained_var_new:0.530
# batch i:99, episode_len:8
# kl:0.02205,lr_multiplier:0.444,loss:3.2597084045410156,entropy:2.759035348892212,explained_var_old:0.417,explained_var_new:0.499
# batch i:100, episode_len:10
# kl:0.02456,lr_multiplier:0.444,loss:3.1769213676452637,entropy:2.760329484939575,explained_var_old:0.444,explained_var_new:0.535
# current self-play batch: 100
# num_playouts:1000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:10
# kl:0.02605,lr_multiplier:0.444,loss:3.3173608779907227,entropy:2.7831456661224365,explained_var_old:0.408,explained_var_new:0.479
# batch i:102, episode_len:11
# kl:0.01878,lr_multiplier:0.444,loss:3.312124252319336,entropy:2.7538821697235107,explained_var_old:0.300,explained_var_new:0.426
# batch i:103, episode_len:7
# kl:0.02255,lr_multiplier:0.444,loss:3.356992483139038,entropy:2.7691917419433594,explained_var_old:0.331,explained_var_new:0.437
# batch i:104, episode_len:16
# kl:0.01831,lr_multiplier:0.444,loss:3.1958882808685303,entropy:2.722531795501709,explained_var_old:0.375,explained_var_new:0.484
# batch i:105, episode_len:9
# kl:0.02217,lr_multiplier:0.444,loss:3.2907419204711914,entropy:2.686136484146118,explained_var_old:0.341,explained_var_new:0.432
# batch i:106, episode_len:14
# kl:0.02413,lr_multiplier:0.444,loss:3.1736252307891846,entropy:2.675971508026123,explained_var_old:0.443,explained_var_new:0.549
# batch i:107, episode_len:15
# kl:0.02373,lr_multiplier:0.444,loss:3.2018771171569824,entropy:2.696228265762329,explained_var_old:0.411,explained_var_new:0.498
# batch i:108, episode_len:7
# kl:0.02260,lr_multiplier:0.444,loss:3.1531331539154053,entropy:2.730480194091797,explained_var_old:0.462,explained_var_new:0.547
# batch i:109, episode_len:19
# kl:0.02782,lr_multiplier:0.444,loss:3.1620450019836426,entropy:2.685441017150879,explained_var_old:0.425,explained_var_new:0.527
# batch i:110, episode_len:7
# kl:0.02551,lr_multiplier:0.444,loss:3.3106327056884766,entropy:2.748030185699463,explained_var_old:0.313,explained_var_new:0.421
# batch i:111, episode_len:9
# kl:0.02810,lr_multiplier:0.444,loss:3.236424446105957,entropy:2.6914398670196533,explained_var_old:0.374,explained_var_new:0.485
# batch i:112, episode_len:10
# kl:0.02013,lr_multiplier:0.444,loss:3.2484848499298096,entropy:2.6621549129486084,explained_var_old:0.315,explained_var_new:0.418
# batch i:113, episode_len:9
# kl:0.02408,lr_multiplier:0.444,loss:3.225595235824585,entropy:2.7056241035461426,explained_var_old:0.382,explained_var_new:0.465
# batch i:114, episode_len:11
# kl:0.02744,lr_multiplier:0.444,loss:3.243382453918457,entropy:2.6967456340789795,explained_var_old:0.357,explained_var_new:0.451
# batch i:115, episode_len:7
# kl:0.02833,lr_multiplier:0.444,loss:3.2379555702209473,entropy:2.670560359954834,explained_var_old:0.323,explained_var_new:0.436
# batch i:116, episode_len:9
# kl:0.03759,lr_multiplier:0.444,loss:3.1863200664520264,entropy:2.655022144317627,explained_var_old:0.337,explained_var_new:0.450
# batch i:117, episode_len:7
# kl:0.02021,lr_multiplier:0.444,loss:3.2464990615844727,entropy:2.7027807235717773,explained_var_old:0.369,explained_var_new:0.452
# batch i:118, episode_len:9
# kl:0.03090,lr_multiplier:0.444,loss:3.1534640789031982,entropy:2.668259859085083,explained_var_old:0.397,explained_var_new:0.510
# batch i:119, episode_len:9
# kl:0.02571,lr_multiplier:0.444,loss:3.1724765300750732,entropy:2.6420490741729736,explained_var_old:0.408,explained_var_new:0.506
# batch i:120, episode_len:8
# kl:0.01865,lr_multiplier:0.444,loss:3.159306049346924,entropy:2.675424098968506,explained_var_old:0.397,explained_var_new:0.478
# batch i:121, episode_len:13
# kl:0.02434,lr_multiplier:0.444,loss:3.1076130867004395,entropy:2.597935199737549,explained_var_old:0.406,explained_var_new:0.500
# batch i:122, episode_len:11
# kl:0.02366,lr_multiplier:0.444,loss:3.057377576828003,entropy:2.5878162384033203,explained_var_old:0.462,explained_var_new:0.556
# batch i:123, episode_len:11
# kl:0.03456,lr_multiplier:0.444,loss:3.0237526893615723,entropy:2.562973976135254,explained_var_old:0.403,explained_var_new:0.535
# batch i:124, episode_len:10
# kl:0.02155,lr_multiplier:0.444,loss:3.2113535404205322,entropy:2.654629707336426,explained_var_old:0.349,explained_var_new:0.468
# batch i:125, episode_len:8
# kl:0.02786,lr_multiplier:0.444,loss:3.100468397140503,entropy:2.6448476314544678,explained_var_old:0.359,explained_var_new:0.506
# batch i:126, episode_len:9
# kl:0.02275,lr_multiplier:0.444,loss:3.1174988746643066,entropy:2.613227605819702,explained_var_old:0.407,explained_var_new:0.542
# batch i:127, episode_len:8
# kl:0.02492,lr_multiplier:0.444,loss:3.1196231842041016,entropy:2.6060900688171387,explained_var_old:0.372,explained_var_new:0.508
# batch i:128, episode_len:10
# kl:0.01769,lr_multiplier:0.444,loss:3.146674633026123,entropy:2.6605169773101807,explained_var_old:0.380,explained_var_new:0.508
# batch i:129, episode_len:8
# kl:0.02335,lr_multiplier:0.444,loss:3.082481861114502,entropy:2.6186904907226562,explained_var_old:0.432,explained_var_new:0.543
# batch i:130, episode_len:10
# kl:0.01679,lr_multiplier:0.444,loss:3.097071647644043,entropy:2.597067356109619,explained_var_old:0.422,explained_var_new:0.553
# batch i:131, episode_len:9
# kl:0.01651,lr_multiplier:0.444,loss:3.0995912551879883,entropy:2.598750591278076,explained_var_old:0.350,explained_var_new:0.485
# batch i:132, episode_len:9
# kl:0.01990,lr_multiplier:0.444,loss:3.0963613986968994,entropy:2.6402838230133057,explained_var_old:0.410,explained_var_new:0.528
# batch i:133, episode_len:7
# kl:0.01463,lr_multiplier:0.444,loss:3.155597686767578,entropy:2.639524221420288,explained_var_old:0.381,explained_var_new:0.473
# batch i:134, episode_len:13
# kl:0.01951,lr_multiplier:0.444,loss:3.0426344871520996,entropy:2.554704427719116,explained_var_old:0.369,explained_var_new:0.505
# batch i:135, episode_len:8
# kl:0.02566,lr_multiplier:0.444,loss:3.0985825061798096,entropy:2.5716443061828613,explained_var_old:0.421,explained_var_new:0.525
# batch i:136, episode_len:18
# kl:0.01607,lr_multiplier:0.444,loss:3.0883665084838867,entropy:2.5588126182556152,explained_var_old:0.341,explained_var_new:0.488
# batch i:137, episode_len:12
# kl:0.01957,lr_multiplier:0.444,loss:3.085411548614502,entropy:2.6179051399230957,explained_var_old:0.445,explained_var_new:0.537
# batch i:138, episode_len:9
# kl:0.02698,lr_multiplier:0.444,loss:3.0840775966644287,entropy:2.604679822921753,explained_var_old:0.381,explained_var_new:0.491
# batch i:139, episode_len:9
# kl:0.01297,lr_multiplier:0.444,loss:3.1335010528564453,entropy:2.6067955493927,explained_var_old:0.379,explained_var_new:0.498
# batch i:140, episode_len:17
# kl:0.02065,lr_multiplier:0.444,loss:3.020375967025757,entropy:2.544679641723633,explained_var_old:0.429,explained_var_new:0.521
# batch i:141, episode_len:11
# kl:0.01705,lr_multiplier:0.444,loss:3.0747110843658447,entropy:2.5525479316711426,explained_var_old:0.415,explained_var_new:0.519
# batch i:142, episode_len:9
# kl:0.02006,lr_multiplier:0.444,loss:3.052689790725708,entropy:2.5452754497528076,explained_var_old:0.352,explained_var_new:0.504
# batch i:143, episode_len:10
# kl:0.02377,lr_multiplier:0.444,loss:3.050468683242798,entropy:2.5704612731933594,explained_var_old:0.435,explained_var_new:0.519
# batch i:144, episode_len:7
# kl:0.03038,lr_multiplier:0.444,loss:2.986905813217163,entropy:2.5281941890716553,explained_var_old:0.399,explained_var_new:0.527
# batch i:145, episode_len:7
# kl:0.02304,lr_multiplier:0.444,loss:2.945988655090332,entropy:2.5046777725219727,explained_var_old:0.490,explained_var_new:0.545
# batch i:146, episode_len:12
# kl:0.02284,lr_multiplier:0.444,loss:3.077179431915283,entropy:2.550835609436035,explained_var_old:0.398,explained_var_new:0.495
# batch i:147, episode_len:12
# kl:0.03089,lr_multiplier:0.444,loss:3.076451301574707,entropy:2.539973735809326,explained_var_old:0.371,explained_var_new:0.472
# batch i:148, episode_len:9
# kl:0.01442,lr_multiplier:0.444,loss:3.1194396018981934,entropy:2.5706992149353027,explained_var_old:0.357,explained_var_new:0.471
# batch i:149, episode_len:7
# kl:0.02618,lr_multiplier:0.444,loss:2.925508499145508,entropy:2.525930881500244,explained_var_old:0.461,explained_var_new:0.550
# batch i:150, episode_len:9
# kl:0.03345,lr_multiplier:0.444,loss:3.013451337814331,entropy:2.5589146614074707,explained_var_old:0.402,explained_var_new:0.531
# current self-play batch: 150
# num_playouts:1000, win: 4, lose: 6, tie:0
# batch i:151, episode_len:14
# kl:0.03842,lr_multiplier:0.444,loss:3.070168972015381,entropy:2.484285593032837,explained_var_old:0.359,explained_var_new:0.466
# batch i:152, episode_len:12
# kl:0.04911,lr_multiplier:0.296,loss:2.953975200653076,entropy:2.5097293853759766,explained_var_old:0.437,explained_var_new:0.538
# batch i:153, episode_len:7
# kl:0.01971,lr_multiplier:0.296,loss:3.0231008529663086,entropy:2.5619444847106934,explained_var_old:0.390,explained_var_new:0.465
# batch i:154, episode_len:20
# kl:0.02150,lr_multiplier:0.296,loss:3.0872626304626465,entropy:2.5392239093780518,explained_var_old:0.329,explained_var_new:0.420
# batch i:155, episode_len:10
# kl:0.02014,lr_multiplier:0.296,loss:2.9540109634399414,entropy:2.4984517097473145,explained_var_old:0.442,explained_var_new:0.515
# batch i:156, episode_len:8
# kl:0.01895,lr_multiplier:0.296,loss:3.062812328338623,entropy:2.4945859909057617,explained_var_old:0.383,explained_var_new:0.456
# batch i:157, episode_len:8
# kl:0.01195,lr_multiplier:0.296,loss:3.081563949584961,entropy:2.5317604541778564,explained_var_old:0.376,explained_var_new:0.452
# batch i:158, episode_len:9
# kl:0.02038,lr_multiplier:0.296,loss:3.067793130874634,entropy:2.500250816345215,explained_var_old:0.410,explained_var_new:0.469
# batch i:159, episode_len:14
# kl:0.01854,lr_multiplier:0.296,loss:2.94174861907959,entropy:2.4559881687164307,explained_var_old:0.398,explained_var_new:0.471
# batch i:160, episode_len:10
# kl:0.01230,lr_multiplier:0.296,loss:3.0469439029693604,entropy:2.5022454261779785,explained_var_old:0.358,explained_var_new:0.435
# batch i:161, episode_len:9
# kl:0.01815,lr_multiplier:0.296,loss:2.946506977081299,entropy:2.4515085220336914,explained_var_old:0.426,explained_var_new:0.480
# batch i:162, episode_len:14
# kl:0.00894,lr_multiplier:0.444,loss:2.898338794708252,entropy:2.423567056655884,explained_var_old:0.411,explained_var_new:0.486
# batch i:163, episode_len:9
# kl:0.03032,lr_multiplier:0.444,loss:2.9237308502197266,entropy:2.401637315750122,explained_var_old:0.403,explained_var_new:0.512
# batch i:164, episode_len:7
# kl:0.02775,lr_multiplier:0.444,loss:2.9573006629943848,entropy:2.47714900970459,explained_var_old:0.394,explained_var_new:0.499
# batch i:165, episode_len:7
# kl:0.02215,lr_multiplier:0.444,loss:2.920219659805298,entropy:2.4118099212646484,explained_var_old:0.406,explained_var_new:0.520
# batch i:166, episode_len:9
# kl:0.03206,lr_multiplier:0.444,loss:3.042410373687744,entropy:2.454345703125,explained_var_old:0.313,explained_var_new:0.435
# batch i:167, episode_len:14
# kl:0.02348,lr_multiplier:0.444,loss:2.8629581928253174,entropy:2.4468796253204346,explained_var_old:0.473,explained_var_new:0.549
# batch i:168, episode_len:7
# kl:0.01915,lr_multiplier:0.444,loss:2.9026780128479004,entropy:2.412294387817383,explained_var_old:0.405,explained_var_new:0.503
# batch i:169, episode_len:7
# kl:0.02035,lr_multiplier:0.444,loss:2.8709733486175537,entropy:2.4121620655059814,explained_var_old:0.435,explained_var_new:0.551
# batch i:170, episode_len:13
# kl:0.02320,lr_multiplier:0.444,loss:2.924060821533203,entropy:2.445443868637085,explained_var_old:0.416,explained_var_new:0.529
# batch i:171, episode_len:9
# kl:0.02681,lr_multiplier:0.444,loss:2.9122376441955566,entropy:2.4123623371124268,explained_var_old:0.422,explained_var_new:0.523
# batch i:172, episode_len:10
# kl:0.02068,lr_multiplier:0.444,loss:2.9155728816986084,entropy:2.391159772872925,explained_var_old:0.441,explained_var_new:0.537
# batch i:173, episode_len:8
# kl:0.02467,lr_multiplier:0.444,loss:2.937955141067505,entropy:2.4309487342834473,explained_var_old:0.352,explained_var_new:0.466
# batch i:174, episode_len:8
# kl:0.03256,lr_multiplier:0.444,loss:2.843052864074707,entropy:2.3875789642333984,explained_var_old:0.439,explained_var_new:0.540
# batch i:175, episode_len:9
# kl:0.03454,lr_multiplier:0.444,loss:2.8123855590820312,entropy:2.365018844604492,explained_var_old:0.495,explained_var_new:0.570
# batch i:176, episode_len:16
# kl:0.02483,lr_multiplier:0.444,loss:2.8845505714416504,entropy:2.4114949703216553,explained_var_old:0.391,explained_var_new:0.510
# batch i:177, episode_len:8
# kl:0.03176,lr_multiplier:0.444,loss:2.8599801063537598,entropy:2.390371799468994,explained_var_old:0.430,explained_var_new:0.519
# batch i:178, episode_len:11
# kl:0.02378,lr_multiplier:0.444,loss:2.816843032836914,entropy:2.3911073207855225,explained_var_old:0.454,explained_var_new:0.565
# batch i:179, episode_len:16
# kl:0.03362,lr_multiplier:0.444,loss:2.848860263824463,entropy:2.317017078399658,explained_var_old:0.358,explained_var_new:0.468
# batch i:180, episode_len:17
# kl:0.03224,lr_multiplier:0.444,loss:2.7719192504882812,entropy:2.301910877227783,explained_var_old:0.483,explained_var_new:0.587
# batch i:181, episode_len:8
# kl:0.04191,lr_multiplier:0.296,loss:2.829577922821045,entropy:2.3059029579162598,explained_var_old:0.385,explained_var_new:0.504
# batch i:182, episode_len:9
# kl:0.02138,lr_multiplier:0.296,loss:2.9924800395965576,entropy:2.4241151809692383,explained_var_old:0.337,explained_var_new:0.424
# batch i:183, episode_len:11
# kl:0.01786,lr_multiplier:0.296,loss:2.9121837615966797,entropy:2.3572402000427246,explained_var_old:0.325,explained_var_new:0.436
# batch i:184, episode_len:9
# kl:0.02065,lr_multiplier:0.296,loss:2.85654354095459,entropy:2.39821195602417,explained_var_old:0.433,explained_var_new:0.510
# batch i:185, episode_len:9
# kl:0.01344,lr_multiplier:0.296,loss:2.8519861698150635,entropy:2.3109939098358154,explained_var_old:0.393,explained_var_new:0.469
# batch i:186, episode_len:7
# kl:0.01978,lr_multiplier:0.296,loss:2.840186834335327,entropy:2.357935905456543,explained_var_old:0.448,explained_var_new:0.519
# batch i:187, episode_len:10
# kl:0.01890,lr_multiplier:0.296,loss:2.8781259059906006,entropy:2.3389816284179688,explained_var_old:0.354,explained_var_new:0.440
# batch i:188, episode_len:9
# kl:0.01720,lr_multiplier:0.296,loss:2.8320114612579346,entropy:2.350472927093506,explained_var_old:0.389,explained_var_new:0.460
# batch i:189, episode_len:10
# kl:0.01712,lr_multiplier:0.296,loss:2.794914722442627,entropy:2.245820999145508,explained_var_old:0.402,explained_var_new:0.483
# batch i:190, episode_len:7
# kl:0.02115,lr_multiplier:0.296,loss:2.8852734565734863,entropy:2.3430750370025635,explained_var_old:0.330,explained_var_new:0.454
# batch i:191, episode_len:8
# kl:0.01323,lr_multiplier:0.296,loss:2.8374886512756348,entropy:2.3416502475738525,explained_var_old:0.409,explained_var_new:0.481
# batch i:192, episode_len:15
# kl:0.02242,lr_multiplier:0.296,loss:2.756096363067627,entropy:2.2673254013061523,explained_var_old:0.415,explained_var_new:0.509
# batch i:193, episode_len:10
# kl:0.01910,lr_multiplier:0.296,loss:2.797233819961548,entropy:2.2821273803710938,explained_var_old:0.448,explained_var_new:0.506
# batch i:194, episode_len:8
# kl:0.01612,lr_multiplier:0.296,loss:2.8169403076171875,entropy:2.287071704864502,explained_var_old:0.405,explained_var_new:0.484
# batch i:195, episode_len:10
# kl:0.01430,lr_multiplier:0.296,loss:2.831347703933716,entropy:2.3506698608398438,explained_var_old:0.415,explained_var_new:0.487
# batch i:196, episode_len:7
# kl:0.01509,lr_multiplier:0.296,loss:2.7313380241394043,entropy:2.237621545791626,explained_var_old:0.404,explained_var_new:0.515
# batch i:197, episode_len:11
# kl:0.02094,lr_multiplier:0.296,loss:2.760876178741455,entropy:2.2386674880981445,explained_var_old:0.384,explained_var_new:0.447
# batch i:198, episode_len:13
# kl:0.01793,lr_multiplier:0.296,loss:2.788123369216919,entropy:2.260955572128296,explained_var_old:0.403,explained_var_new:0.493
# batch i:199, episode_len:10
# kl:0.01873,lr_multiplier:0.296,loss:2.7900030612945557,entropy:2.2588236331939697,explained_var_old:0.383,explained_var_new:0.460
# batch i:200, episode_len:14
# kl:0.02017,lr_multiplier:0.296,loss:2.8356032371520996,entropy:2.3249855041503906,explained_var_old:0.357,explained_var_new:0.440
# current self-play batch: 200
# num_playouts:1000, win: 7, lose: 3, tie:0
# batch i:201, episode_len:13
# kl:0.01775,lr_multiplier:0.296,loss:2.700106382369995,entropy:2.20078182220459,explained_var_old:0.443,explained_var_new:0.497
# batch i:202, episode_len:10
# kl:0.01053,lr_multiplier:0.296,loss:2.784437656402588,entropy:2.2339887619018555,explained_var_old:0.398,explained_var_new:0.496
# batch i:203, episode_len:8
# kl:0.02459,lr_multiplier:0.296,loss:2.759364128112793,entropy:2.3242037296295166,explained_var_old:0.412,explained_var_new:0.510
# batch i:204, episode_len:7
# kl:0.01822,lr_multiplier:0.296,loss:2.7787091732025146,entropy:2.217085123062134,explained_var_old:0.409,explained_var_new:0.464
# batch i:205, episode_len:9
# kl:0.00934,lr_multiplier:0.444,loss:2.776167869567871,entropy:2.275787591934204,explained_var_old:0.381,explained_var_new:0.475
# batch i:206, episode_len:7
# kl:0.02202,lr_multiplier:0.444,loss:2.653968572616577,entropy:2.233598232269287,explained_var_old:0.448,explained_var_new:0.521
# batch i:207, episode_len:8
# kl:0.01874,lr_multiplier:0.444,loss:2.725973606109619,entropy:2.2343220710754395,explained_var_old:0.401,explained_var_new:0.496
# batch i:208, episode_len:7
# kl:0.02239,lr_multiplier:0.444,loss:2.721208333969116,entropy:2.215615749359131,explained_var_old:0.373,explained_var_new:0.480
# batch i:209, episode_len:12
# kl:0.02897,lr_multiplier:0.444,loss:2.700042963027954,entropy:2.187838315963745,explained_var_old:0.400,explained_var_new:0.512
# batch i:210, episode_len:9
# kl:0.01745,lr_multiplier:0.444,loss:2.6485605239868164,entropy:2.1485230922698975,explained_var_old:0.396,explained_var_new:0.491
# batch i:211, episode_len:12
# kl:0.02270,lr_multiplier:0.444,loss:2.7581326961517334,entropy:2.227566719055176,explained_var_old:0.425,explained_var_new:0.498
# batch i:212, episode_len:7
# kl:0.01619,lr_multiplier:0.444,loss:2.7190229892730713,entropy:2.203049898147583,explained_var_old:0.394,explained_var_new:0.484
# batch i:213, episode_len:9
# kl:0.03797,lr_multiplier:0.444,loss:2.748936891555786,entropy:2.1517200469970703,explained_var_old:0.353,explained_var_new:0.466
# batch i:214, episode_len:9
# kl:0.02135,lr_multiplier:0.444,loss:2.6839780807495117,entropy:2.183476448059082,explained_var_old:0.416,explained_var_new:0.513
# batch i:215, episode_len:10
# kl:0.03104,lr_multiplier:0.444,loss:2.7136800289154053,entropy:2.1925857067108154,explained_var_old:0.377,explained_var_new:0.481
# batch i:216, episode_len:8
# kl:0.02582,lr_multiplier:0.444,loss:2.6377432346343994,entropy:2.1112160682678223,explained_var_old:0.395,explained_var_new:0.499
# batch i:217, episode_len:11
# kl:0.02770,lr_multiplier:0.444,loss:2.7333052158355713,entropy:2.2295796871185303,explained_var_old:0.333,explained_var_new:0.444
# batch i:218, episode_len:8
# kl:0.01947,lr_multiplier:0.444,loss:2.7045013904571533,entropy:2.24638032913208,explained_var_old:0.394,explained_var_new:0.520
# batch i:219, episode_len:10
# kl:0.02824,lr_multiplier:0.444,loss:2.6210289001464844,entropy:2.132753849029541,explained_var_old:0.403,explained_var_new:0.513
# batch i:220, episode_len:9
# kl:0.03139,lr_multiplier:0.444,loss:2.646589994430542,entropy:2.0960161685943604,explained_var_old:0.363,explained_var_new:0.497
# batch i:221, episode_len:8
# kl:0.02867,lr_multiplier:0.444,loss:2.7244529724121094,entropy:2.152524471282959,explained_var_old:0.335,explained_var_new:0.460
# batch i:222, episode_len:7
# kl:0.02771,lr_multiplier:0.444,loss:2.6877670288085938,entropy:2.170320510864258,explained_var_old:0.368,explained_var_new:0.450
# batch i:223, episode_len:10
# kl:0.02611,lr_multiplier:0.444,loss:2.6471126079559326,entropy:2.1072916984558105,explained_var_old:0.329,explained_var_new:0.457
# batch i:224, episode_len:11
# kl:0.02075,lr_multiplier:0.444,loss:2.578092098236084,entropy:2.1296534538269043,explained_var_old:0.445,explained_var_new:0.533
# batch i:225, episode_len:9
# kl:0.02046,lr_multiplier:0.444,loss:2.680757999420166,entropy:2.157679557800293,explained_var_old:0.362,explained_var_new:0.480
# batch i:226, episode_len:10
# kl:0.01799,lr_multiplier:0.444,loss:2.681267499923706,entropy:2.1540920734405518,explained_var_old:0.387,explained_var_new:0.471
# batch i:227, episode_len:14
# kl:0.02469,lr_multiplier:0.444,loss:2.631957530975342,entropy:2.132659912109375,explained_var_old:0.394,explained_var_new:0.499
# batch i:228, episode_len:13
# kl:0.01994,lr_multiplier:0.444,loss:2.666132926940918,entropy:2.0980939865112305,explained_var_old:0.375,explained_var_new:0.466
# batch i:229, episode_len:11
# kl:0.03293,lr_multiplier:0.444,loss:2.6333229541778564,entropy:2.097794771194458,explained_var_old:0.348,explained_var_new:0.455
# batch i:230, episode_len:9
# kl:0.02630,lr_multiplier:0.444,loss:2.5821101665496826,entropy:2.124967575073242,explained_var_old:0.407,explained_var_new:0.518
# batch i:231, episode_len:7
# kl:0.02913,lr_multiplier:0.444,loss:2.6443428993225098,entropy:2.179814100265503,explained_var_old:0.385,explained_var_new:0.489
# batch i:232, episode_len:7
# kl:0.02577,lr_multiplier:0.444,loss:2.65096378326416,entropy:2.0890207290649414,explained_var_old:0.351,explained_var_new:0.464
# batch i:233, episode_len:7
# kl:0.02617,lr_multiplier:0.444,loss:2.60910964012146,entropy:2.0764639377593994,explained_var_old:0.389,explained_var_new:0.473
# batch i:234, episode_len:9
# kl:0.02852,lr_multiplier:0.444,loss:2.5914978981018066,entropy:2.092881917953491,explained_var_old:0.416,explained_var_new:0.512
# batch i:235, episode_len:8
# kl:0.03037,lr_multiplier:0.444,loss:2.678795099258423,entropy:2.1093618869781494,explained_var_old:0.344,explained_var_new:0.475
# batch i:236, episode_len:8
# kl:0.03105,lr_multiplier:0.444,loss:2.5796754360198975,entropy:2.1002936363220215,explained_var_old:0.417,explained_var_new:0.513
# batch i:237, episode_len:8
# kl:0.03765,lr_multiplier:0.444,loss:2.653843402862549,entropy:2.1152472496032715,explained_var_old:0.343,explained_var_new:0.459
# batch i:238, episode_len:9
# kl:0.03806,lr_multiplier:0.444,loss:2.609517812728882,entropy:2.037834405899048,explained_var_old:0.343,explained_var_new:0.452
# batch i:239, episode_len:13
# kl:0.03425,lr_multiplier:0.444,loss:2.6385750770568848,entropy:2.1117451190948486,explained_var_old:0.347,explained_var_new:0.468
# batch i:240, episode_len:9
# kl:0.03752,lr_multiplier:0.444,loss:2.615234136581421,entropy:2.101499557495117,explained_var_old:0.316,explained_var_new:0.456
# batch i:241, episode_len:9
# kl:0.03793,lr_multiplier:0.444,loss:2.5951783657073975,entropy:2.0821359157562256,explained_var_old:0.389,explained_var_new:0.492
# batch i:242, episode_len:7
# kl:0.02448,lr_multiplier:0.444,loss:2.5480871200561523,entropy:2.048278331756592,explained_var_old:0.401,explained_var_new:0.487
# batch i:243, episode_len:11
# kl:0.03278,lr_multiplier:0.444,loss:2.5583348274230957,entropy:1.9893914461135864,explained_var_old:0.353,explained_var_new:0.447
# batch i:244, episode_len:9
# kl:0.02626,lr_multiplier:0.444,loss:2.5201714038848877,entropy:2.029402256011963,explained_var_old:0.421,explained_var_new:0.518
# batch i:245, episode_len:7
# kl:0.02527,lr_multiplier:0.444,loss:2.6323702335357666,entropy:2.0339736938476562,explained_var_old:0.352,explained_var_new:0.431
# batch i:246, episode_len:12
# kl:0.01789,lr_multiplier:0.444,loss:2.537046432495117,entropy:2.016784191131592,explained_var_old:0.356,explained_var_new:0.457
# batch i:247, episode_len:7
# kl:0.02715,lr_multiplier:0.444,loss:2.588898181915283,entropy:2.0545971393585205,explained_var_old:0.383,explained_var_new:0.481
# batch i:248, episode_len:10
# kl:0.01871,lr_multiplier:0.444,loss:2.5874578952789307,entropy:2.09616756439209,explained_var_old:0.390,explained_var_new:0.478
# batch i:249, episode_len:8
# kl:0.03148,lr_multiplier:0.444,loss:2.5422563552856445,entropy:2.01725697517395,explained_var_old:0.378,explained_var_new:0.494
# batch i:250, episode_len:14
# kl:0.02593,lr_multiplier:0.444,loss:2.5586154460906982,entropy:2.065788745880127,explained_var_old:0.423,explained_var_new:0.529
# current self-play batch: 250
# num_playouts:1000, win: 10, lose: 0, tie:0
# 发现新的最优策略，进行策略更新
# batch i:251, episode_len:7
# kl:0.02654,lr_multiplier:0.444,loss:2.4406888484954834,entropy:2.001293897628784,explained_var_old:0.428,explained_var_new:0.522
# batch i:252, episode_len:7
# kl:0.02658,lr_multiplier:0.444,loss:2.5020253658294678,entropy:2.0414834022521973,explained_var_old:0.394,explained_var_new:0.514
# batch i:253, episode_len:9
# kl:0.02358,lr_multiplier:0.444,loss:2.5478317737579346,entropy:2.0491726398468018,explained_var_old:0.382,explained_var_new:0.489
# batch i:254, episode_len:9
# kl:0.02183,lr_multiplier:0.444,loss:2.5297510623931885,entropy:1.9980874061584473,explained_var_old:0.385,explained_var_new:0.487
# batch i:255, episode_len:14
# kl:0.02787,lr_multiplier:0.444,loss:2.536269187927246,entropy:2.0063464641571045,explained_var_old:0.414,explained_var_new:0.485
# batch i:256, episode_len:12
# kl:0.03227,lr_multiplier:0.444,loss:2.5256969928741455,entropy:2.076978921890259,explained_var_old:0.386,explained_var_new:0.498
# batch i:257, episode_len:11
# kl:0.02691,lr_multiplier:0.444,loss:2.4798953533172607,entropy:1.9976284503936768,explained_var_old:0.419,explained_var_new:0.514
# batch i:258, episode_len:7
# kl:0.02814,lr_multiplier:0.444,loss:2.3469974994659424,entropy:1.9021470546722412,explained_var_old:0.455,explained_var_new:0.565
# batch i:259, episode_len:11
# kl:0.03308,lr_multiplier:0.444,loss:2.4630050659179688,entropy:2.024383306503296,explained_var_old:0.430,explained_var_new:0.524
# batch i:260, episode_len:12
# kl:0.02153,lr_multiplier:0.444,loss:2.4297449588775635,entropy:1.9932868480682373,explained_var_old:0.460,explained_var_new:0.543
# batch i:261, episode_len:11
# kl:0.02240,lr_multiplier:0.444,loss:2.519278049468994,entropy:1.9820687770843506,explained_var_old:0.347,explained_var_new:0.459
# batch i:262, episode_len:8
# kl:0.03242,lr_multiplier:0.444,loss:2.4357047080993652,entropy:1.9890377521514893,explained_var_old:0.436,explained_var_new:0.539
# batch i:263, episode_len:9
# kl:0.03054,lr_multiplier:0.444,loss:2.4446210861206055,entropy:1.9422239065170288,explained_var_old:0.409,explained_var_new:0.529
# batch i:264, episode_len:15
# kl:0.03141,lr_multiplier:0.444,loss:2.502858877182007,entropy:2.034672498703003,explained_var_old:0.393,explained_var_new:0.502
# batch i:265, episode_len:7
# kl:0.03481,lr_multiplier:0.444,loss:2.4672069549560547,entropy:1.9101229906082153,explained_var_old:0.361,explained_var_new:0.463
# batch i:266, episode_len:7
# kl:0.02913,lr_multiplier:0.444,loss:2.494593858718872,entropy:2.020200252532959,explained_var_old:0.374,explained_var_new:0.492
# batch i:267, episode_len:9
# kl:0.03156,lr_multiplier:0.444,loss:2.445465326309204,entropy:1.933334231376648,explained_var_old:0.400,explained_var_new:0.488
# batch i:268, episode_len:15
# kl:0.02514,lr_multiplier:0.444,loss:2.461216926574707,entropy:1.9460042715072632,explained_var_old:0.352,explained_var_new:0.497
# batch i:269, episode_len:10
# kl:0.02413,lr_multiplier:0.444,loss:2.5122175216674805,entropy:1.9755604267120361,explained_var_old:0.378,explained_var_new:0.465
# batch i:270, episode_len:7
# kl:0.02720,lr_multiplier:0.444,loss:2.3934569358825684,entropy:1.876032829284668,explained_var_old:0.406,explained_var_new:0.511
# batch i:271, episode_len:11
# kl:0.02314,lr_multiplier:0.444,loss:2.352447509765625,entropy:1.9349764585494995,explained_var_old:0.425,explained_var_new:0.534
# batch i:272, episode_len:8
# kl:0.02129,lr_multiplier:0.444,loss:2.4299468994140625,entropy:1.880601167678833,explained_var_old:0.347,explained_var_new:0.439
# batch i:273, episode_len:7
# kl:0.04157,lr_multiplier:0.296,loss:2.4372215270996094,entropy:1.9248340129852295,explained_var_old:0.374,explained_var_new:0.486
# batch i:274, episode_len:13
# kl:0.01174,lr_multiplier:0.296,loss:2.44374418258667,entropy:1.8886163234710693,explained_var_old:0.411,explained_var_new:0.494
# batch i:275, episode_len:9
# kl:0.01700,lr_multiplier:0.296,loss:2.3862738609313965,entropy:1.882565975189209,explained_var_old:0.416,explained_var_new:0.473
# batch i:276, episode_len:7
# kl:0.01416,lr_multiplier:0.296,loss:2.3545656204223633,entropy:1.8907573223114014,explained_var_old:0.410,explained_var_new:0.495
# batch i:277, episode_len:10
# kl:0.01104,lr_multiplier:0.296,loss:2.3453240394592285,entropy:1.9069463014602661,explained_var_old:0.470,explained_var_new:0.528
# batch i:278, episode_len:11
# kl:0.01395,lr_multiplier:0.296,loss:2.311312198638916,entropy:1.8327962160110474,explained_var_old:0.455,explained_var_new:0.527
# batch i:279, episode_len:9
# kl:0.01621,lr_multiplier:0.296,loss:2.396878480911255,entropy:1.887662410736084,explained_var_old:0.415,explained_var_new:0.490
# batch i:280, episode_len:7
# kl:0.01195,lr_multiplier:0.296,loss:2.3979880809783936,entropy:1.8783926963806152,explained_var_old:0.471,explained_var_new:0.514
# batch i:281, episode_len:7
# kl:0.01165,lr_multiplier:0.296,loss:2.411486864089966,entropy:1.9107906818389893,explained_var_old:0.437,explained_var_new:0.515
# batch i:282, episode_len:9
# kl:0.01317,lr_multiplier:0.296,loss:2.421205520629883,entropy:1.9900106191635132,explained_var_old:0.454,explained_var_new:0.520
# batch i:283, episode_len:8
# kl:0.01431,lr_multiplier:0.296,loss:2.3999478816986084,entropy:1.8991472721099854,explained_var_old:0.418,explained_var_new:0.489
# batch i:284, episode_len:14
# kl:0.01186,lr_multiplier:0.296,loss:2.3917629718780518,entropy:1.8996875286102295,explained_var_old:0.421,explained_var_new:0.495
# batch i:285, episode_len:8
# kl:0.01859,lr_multiplier:0.296,loss:2.3504996299743652,entropy:1.803544521331787,explained_var_old:0.413,explained_var_new:0.471
# batch i:286, episode_len:9
# kl:0.01167,lr_multiplier:0.296,loss:2.3807802200317383,entropy:1.8491981029510498,explained_var_old:0.414,explained_var_new:0.473
# batch i:287, episode_len:9
# kl:0.01622,lr_multiplier:0.296,loss:2.424917459487915,entropy:1.8873642683029175,explained_var_old:0.388,explained_var_new:0.475
# batch i:288, episode_len:9
# kl:0.02175,lr_multiplier:0.296,loss:2.380439281463623,entropy:1.8428806066513062,explained_var_old:0.392,explained_var_new:0.490
# batch i:289, episode_len:13
# kl:0.02097,lr_multiplier:0.296,loss:2.368657350540161,entropy:1.8830749988555908,explained_var_old:0.398,explained_var_new:0.456
# batch i:290, episode_len:10
# kl:0.02158,lr_multiplier:0.296,loss:2.381776809692383,entropy:1.8439604043960571,explained_var_old:0.386,explained_var_new:0.460
# batch i:291, episode_len:12
# kl:0.02053,lr_multiplier:0.296,loss:2.3281264305114746,entropy:1.8611301183700562,explained_var_old:0.398,explained_var_new:0.481
# batch i:292, episode_len:7
# kl:0.01027,lr_multiplier:0.296,loss:2.3991470336914062,entropy:1.9024797677993774,explained_var_old:0.412,explained_var_new:0.467
# batch i:293, episode_len:12
# kl:0.01065,lr_multiplier:0.296,loss:2.4747471809387207,entropy:1.898327112197876,explained_var_old:0.373,explained_var_new:0.441
# batch i:294, episode_len:7
# kl:0.01759,lr_multiplier:0.296,loss:2.314596176147461,entropy:1.7733943462371826,explained_var_old:0.364,explained_var_new:0.441
# batch i:295, episode_len:7
# kl:0.01351,lr_multiplier:0.296,loss:2.3314671516418457,entropy:1.847535490989685,explained_var_old:0.363,explained_var_new:0.461
# batch i:296, episode_len:11
# kl:0.03178,lr_multiplier:0.296,loss:2.376382350921631,entropy:1.7244700193405151,explained_var_old:0.341,explained_var_new:0.424
# batch i:297, episode_len:12
# kl:0.03617,lr_multiplier:0.296,loss:2.4117321968078613,entropy:1.9296420812606812,explained_var_old:0.354,explained_var_new:0.436
# batch i:298, episode_len:7
# kl:0.02534,lr_multiplier:0.296,loss:2.4511075019836426,entropy:1.8795047998428345,explained_var_old:0.353,explained_var_new:0.436
# batch i:299, episode_len:11
# kl:0.00624,lr_multiplier:0.444,loss:2.36963152885437,entropy:1.8317549228668213,explained_var_old:0.376,explained_var_new:0.435
# batch i:300, episode_len:7
# kl:0.01819,lr_multiplier:0.444,loss:2.3192059993743896,entropy:1.8341630697250366,explained_var_old:0.400,explained_var_new:0.484
# current self-play batch: 300
# num_playouts:2000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:301, episode_len:8
# kl:0.02208,lr_multiplier:0.444,loss:2.272566080093384,entropy:1.8009250164031982,explained_var_old:0.409,explained_var_new:0.507
# batch i:302, episode_len:8
# kl:0.02390,lr_multiplier:0.444,loss:2.2745227813720703,entropy:1.7609856128692627,explained_var_old:0.402,explained_var_new:0.509
# batch i:303, episode_len:11
# kl:0.02190,lr_multiplier:0.444,loss:2.372828245162964,entropy:1.8268412351608276,explained_var_old:0.358,explained_var_new:0.460
# batch i:304, episode_len:9
# ...
# batch i:400, episode_len:7
# kl:0.03199,lr_multiplier:0.296,loss:2.1677448749542236,entropy:1.5446759462356567,explained_var_old:0.362,explained_var_new:0.447
# current self-play batch: 400
# num_playouts:2000, win: 6, lose: 4, tie:0
# batch i:401, episode_len:11
# kl:0.03133,lr_multiplier:0.296,loss:2.2104811668395996,entropy:1.6535871028900146,explained_var_old:0.330,explained_var_new:0.406
# batch i:402, episode_len:8
# kl:0.01890,lr_multiplier:0.296,loss:2.0966811180114746,entropy:1.5686019659042358,explained_var_old:0.387,explained_var_new:0.481
# batch i:403, episode_len:7
# kl:0.02170,lr_multiplier:0.296,loss:2.1375796794891357,entropy:1.557799220085144,explained_var_old:0.333,explained_var_new:0.434
# batch i:404, episode_len:8
# kl:0.01661,lr_multiplier:0.296,loss:2.2060024738311768,entropy:1.6446986198425293,explained_var_old:0.338,explained_var_new:0.405
# batch i:405, episode_len:7
# batch i:406, episode_len:7
# kl:0.01612,lr_multiplier:0.296,loss:2.1097044944763184,entropy:1.5659472942352295,explained_var_old:0.378,explained_var_new:0.467
# batch i:407, episode_len:9
# kl:0.01722,lr_multiplier:0.296,loss:2.167050838470459,entropy:1.5900212526321411,explained_var_old:0.362,explained_var_new:0.423
# batch i:408, episode_len:9
# kl:0.01967,lr_multiplier:0.296,loss:2.1182079315185547,entropy:1.6084771156311035,explained_var_old:0.397,explained_var_new:0.464
# batch i:409, episode_len:15
# kl:0.01797,lr_multiplier:0.296,loss:2.1530921459198,entropy:1.5456560850143433,explained_var_old:0.335,explained_var_new:0.421
# batch i:410, episode_len:9
# kl:0.02863,lr_multiplier:0.296,loss:2.206244945526123,entropy:1.6126718521118164,explained_var_old:0.342,explained_var_new:0.412
# batch i:411, episode_len:14
# kl:0.02603,lr_multiplier:0.296,loss:2.088347911834717,entropy:1.5553700923919678,explained_var_old:0.377,explained_var_new:0.456
# batch i:412, episode_len:10
# kl:0.02678,lr_multiplier:0.296,loss:2.1868467330932617,entropy:1.6532007455825806,explained_var_old:0.359,explained_var_new:0.441
# batch i:413, episode_len:11
# kl:0.01723,lr_multiplier:0.296,loss:2.1715259552001953,entropy:1.6114201545715332,explained_var_old:0.378,explained_var_new:0.455
# batch i:414, episode_len:16
# kl:0.01468,lr_multiplier:0.296,loss:2.091413974761963,entropy:1.64290189743042,explained_var_old:0.424,explained_var_new:0.501
# batch i:415, episode_len:11
# kl:0.02138,lr_multiplier:0.296,loss:2.032888889312744,entropy:1.5773123502731323,explained_var_old:0.460,explained_var_new:0.523
# batch i:416, episode_len:7
# kl:0.01236,lr_multiplier:0.296,loss:2.166348934173584,entropy:1.5897494554519653,explained_var_old:0.400,explained_var_new:0.477
# batch i:417, episode_len:12
# kl:0.01684,lr_multiplier:0.296,loss:2.0819618701934814,entropy:1.5160080194473267,explained_var_old:0.335,explained_var_new:0.429
# batch i:418, episode_len:7
# kl:0.01781,lr_multiplier:0.296,loss:1.995490550994873,entropy:1.4905245304107666,explained_var_old:0.446,explained_var_new:0.500
# batch i:419, episode_len:11
# kl:0.02390,lr_multiplier:0.296,loss:2.0637717247009277,entropy:1.5492982864379883,explained_var_old:0.429,explained_var_new:0.491
# batch i:420, episode_len:19
# kl:0.02296,lr_multiplier:0.296,loss:2.051579475402832,entropy:1.5394041538238525,explained_var_old:0.409,explained_var_new:0.479
# batch i:421, episode_len:9
# kl:0.01679,lr_multiplier:0.296,loss:2.0340843200683594,entropy:1.5835262537002563,explained_var_old:0.435,explained_var_new:0.503
# batch i:422, episode_len:8
# kl:0.01840,lr_multiplier:0.296,loss:2.150989055633545,entropy:1.591320276260376,explained_var_old:0.306,explained_var_new:0.404
# batch i:423, episode_len:9
# kl:0.02344,lr_multiplier:0.296,loss:2.221395969390869,entropy:1.6624397039413452,explained_var_old:0.351,explained_var_new:0.436
# batch i:424, episode_len:11
# kl:0.01461,lr_multiplier:0.296,loss:2.1465401649475098,entropy:1.6347112655639648,explained_var_old:0.404,explained_var_new:0.480
# batch i:425, episode_len:7
# kl:0.02386,lr_multiplier:0.296,loss:2.1481354236602783,entropy:1.5887973308563232,explained_var_old:0.347,explained_var_new:0.438
# batch i:426, episode_len:10
# kl:0.01581,lr_multiplier:0.296,loss:2.1742820739746094,entropy:1.6549676656723022,explained_var_old:0.402,explained_var_new:0.475
# batch i:427, episode_len:9
# kl:0.01630,lr_multiplier:0.296,loss:2.0770275592803955,entropy:1.5992399454116821,explained_var_old:0.423,explained_var_new:0.494
# batch i:428, episode_len:14
# kl:0.01306,lr_multiplier:0.296,loss:2.1532163619995117,entropy:1.6370853185653687,explained_var_old:0.375,explained_var_new:0.454
# batch i:429, episode_len:7
# kl:0.01473,lr_multiplier:0.296,loss:2.1789040565490723,entropy:1.6291148662567139,explained_var_old:0.343,explained_var_new:0.414
# batch i:430, episode_len:13
# kl:0.02280,lr_multiplier:0.296,loss:2.0704431533813477,entropy:1.52283775806427,explained_var_old:0.392,explained_var_new:0.458
# batch i:431, episode_len:8
# kl:0.02063,lr_multiplier:0.296,loss:2.085730791091919,entropy:1.5853168964385986,explained_var_old:0.404,explained_var_new:0.485
# batch i:432, episode_len:7
# kl:0.02017,lr_multiplier:0.296,loss:2.1290202140808105,entropy:1.5752241611480713,explained_var_old:0.403,explained_var_new:0.479
# batch i:433, episode_len:11
# kl:0.02194,lr_multiplier:0.296,loss:2.0577125549316406,entropy:1.537438988685608,explained_var_old:0.449,explained_var_new:0.500
# batch i:434, episode_len:16
# kl:0.02628,lr_multiplier:0.296,loss:2.091586112976074,entropy:1.5908541679382324,explained_var_old:0.416,explained_var_new:0.477
# batch i:435, episode_len:7
# kl:0.01591,lr_multiplier:0.296,loss:2.0475878715515137,entropy:1.55642569065094,explained_var_old:0.431,explained_var_new:0.503
# batch i:436, episode_len:11
# kl:0.01768,lr_multiplier:0.296,loss:2.1303224563598633,entropy:1.498247504234314,explained_var_old:0.350,explained_var_new:0.415
# batch i:437, episode_len:15
# kl:0.02331,lr_multiplier:0.296,loss:2.101114511489868,entropy:1.5520880222320557,explained_var_old:0.354,explained_var_new:0.440
# batch i:438, episode_len:17
# kl:0.01493,lr_multiplier:0.296,loss:2.092543363571167,entropy:1.5704126358032227,explained_var_old:0.392,explained_var_new:0.473
# batch i:439, episode_len:11
# kl:0.01898,lr_multiplier:0.296,loss:2.0467545986175537,entropy:1.5956239700317383,explained_var_old:0.439,explained_var_new:0.531
# batch i:440, episode_len:10
# kl:0.01961,lr_multiplier:0.296,loss:2.0828583240509033,entropy:1.602433204650879,explained_var_old:0.402,explained_var_new:0.468
# batch i:441, episode_len:9
# kl:0.01528,lr_multiplier:0.296,loss:1.981400966644287,entropy:1.5204432010650635,explained_var_old:0.435,explained_var_new:0.517
# batch i:442, episode_len:8
# kl:0.02198,lr_multiplier:0.296,loss:2.0751757621765137,entropy:1.5787982940673828,explained_var_old:0.421,explained_var_new:0.499
# batch i:443, episode_len:12
# kl:0.01730,lr_multiplier:0.296,loss:2.1435041427612305,entropy:1.5923643112182617,explained_var_old:0.367,explained_var_new:0.439
# batch i:444, episode_len:15
# kl:0.01998,lr_multiplier:0.296,loss:2.096750497817993,entropy:1.5608477592468262,explained_var_old:0.416,explained_var_new:0.489
# batch i:445, episode_len:13
# kl:0.02138,lr_multiplier:0.296,loss:2.1061787605285645,entropy:1.5273398160934448,explained_var_old:0.384,explained_var_new:0.463
# batch i:446, episode_len:13
# kl:0.01303,lr_multiplier:0.296,loss:2.1365342140197754,entropy:1.5564754009246826,explained_var_old:0.324,explained_var_new:0.429
# batch i:447, episode_len:10
# kl:0.01832,lr_multiplier:0.296,loss:2.0825583934783936,entropy:1.5702953338623047,explained_var_old:0.396,explained_var_new:0.456
# batch i:448, episode_len:7
# kl:0.01329,lr_multiplier:0.296,loss:2.0754923820495605,entropy:1.5596328973770142,explained_var_old:0.424,explained_var_new:0.477
# batch i:449, episode_len:9
# kl:0.02036,lr_multiplier:0.296,loss:2.088043689727783,entropy:1.550667643547058,explained_var_old:0.396,explained_var_new:0.470
# batch i:450, episode_len:12
# kl:0.01091,lr_multiplier:0.296,loss:2.080350637435913,entropy:1.560275912284851,explained_var_old:0.411,explained_var_new:0.483
# current self-play batch: 450
# num_playouts:2000, win: 7, lose: 3, tie:0
# batch i:451, episode_len:18
# kl:0.01392,lr_multiplier:0.296,loss:2.1052160263061523,entropy:1.6317055225372314,explained_var_old:0.481,explained_var_new:0.533
# batch i:452, episode_len:7
# kl:0.01481,lr_multiplier:0.296,loss:2.145519733428955,entropy:1.5646166801452637,explained_var_old:0.334,explained_var_new:0.420
# batch i:453, episode_len:13
# kl:0.01374,lr_multiplier:0.296,loss:2.011906862258911,entropy:1.5294244289398193,explained_var_old:0.442,explained_var_new:0.504
# batch i:454, episode_len:8
# kl:0.01796,lr_multiplier:0.296,loss:2.155759334564209,entropy:1.586236596107483,explained_var_old:0.319,explained_var_new:0.412
# batch i:455, episode_len:9
# kl:0.01602,lr_multiplier:0.296,loss:2.10306978225708,entropy:1.5542420148849487,explained_var_old:0.378,explained_var_new:0.451
# batch i:456, episode_len:11
# kl:0.01975,lr_multiplier:0.296,loss:2.070748805999756,entropy:1.5896344184875488,explained_var_old:0.432,explained_var_new:0.515
# batch i:457, episode_len:12
# kl:0.01285,lr_multiplier:0.296,loss:2.0994458198547363,entropy:1.5765372514724731,explained_var_old:0.390,explained_var_new:0.475
# batch i:458, episode_len:9
# kl:0.02393,lr_multiplier:0.296,loss:2.0711259841918945,entropy:1.5233139991760254,explained_var_old:0.381,explained_var_new:0.454
# batch i:459, episode_len:8
# kl:0.01702,lr_multiplier:0.296,loss:2.1349189281463623,entropy:1.6125593185424805,explained_var_old:0.400,explained_var_new:0.466
# batch i:460, episode_len:8
# kl:0.01764,lr_multiplier:0.296,loss:2.062337636947632,entropy:1.5418370962142944,explained_var_old:0.374,explained_var_new:0.447
# batch i:461, episode_len:16
# kl:0.01885,lr_multiplier:0.296,loss:2.0947818756103516,entropy:1.6027865409851074,explained_var_old:0.460,explained_var_new:0.518
# batch i:462, episode_len:13
# kl:0.02054,lr_multiplier:0.296,loss:2.0955753326416016,entropy:1.5772621631622314,explained_var_old:0.422,explained_var_new:0.480
# batch i:463, episode_len:9
# kl:0.02051,lr_multiplier:0.296,loss:2.156048059463501,entropy:1.5887317657470703,explained_var_old:0.381,explained_var_new:0.447
# batch i:464, episode_len:11
# kl:0.02426,lr_multiplier:0.296,loss:2.086512327194214,entropy:1.5739731788635254,explained_var_old:0.392,explained_var_new:0.470
# batch i:465, episode_len:11
# kl:0.02505,lr_multiplier:0.296,loss:1.9919129610061646,entropy:1.5372133255004883,explained_var_old:0.404,explained_var_new:0.480
# batch i:466, episode_len:9
# kl:0.02601,lr_multiplier:0.296,loss:2.021559953689575,entropy:1.5327662229537964,explained_var_old:0.439,explained_var_new:0.531
# batch i:467, episode_len:19
# kl:0.02809,lr_multiplier:0.296,loss:2.2067642211914062,entropy:1.6173319816589355,explained_var_old:0.367,explained_var_new:0.424
# batch i:468, episode_len:13
# kl:0.02668,lr_multiplier:0.296,loss:2.0792407989501953,entropy:1.6166819334030151,explained_var_old:0.420,explained_var_new:0.532
# batch i:469, episode_len:11
# kl:0.01499,lr_multiplier:0.296,loss:2.0440027713775635,entropy:1.5533859729766846,explained_var_old:0.414,explained_var_new:0.483
# batch i:470, episode_len:8
# kl:0.02499,lr_multiplier:0.296,loss:1.976832389831543,entropy:1.5178273916244507,explained_var_old:0.423,explained_var_new:0.516
# batch i:471, episode_len:10
# kl:0.01400,lr_multiplier:0.296,loss:2.086498260498047,entropy:1.5280925035476685,explained_var_old:0.336,explained_var_new:0.431
# batch i:472, episode_len:9
# kl:0.02036,lr_multiplier:0.296,loss:2.1183290481567383,entropy:1.6168705224990845,explained_var_old:0.403,explained_var_new:0.462
# batch i:473, episode_len:9
# kl:0.02196,lr_multiplier:0.296,loss:2.043991804122925,entropy:1.5143520832061768,explained_var_old:0.457,explained_var_new:0.526
# batch i:474, episode_len:16
# kl:0.02133,lr_multiplier:0.296,loss:2.107053756713867,entropy:1.5389657020568848,explained_var_old:0.337,explained_var_new:0.419
# batch i:475, episode_len:16
# kl:0.01846,lr_multiplier:0.296,loss:2.1157195568084717,entropy:1.5411500930786133,explained_var_old:0.373,explained_var_new:0.430
# batch i:476, episode_len:9
# kl:0.02138,lr_multiplier:0.296,loss:2.1038408279418945,entropy:1.5936110019683838,explained_var_old:0.412,explained_var_new:0.472
# batch i:477, episode_len:9
# kl:0.01761,lr_multiplier:0.296,loss:2.1085052490234375,entropy:1.5360904932022095,explained_var_old:0.364,explained_var_new:0.424
# batch i:478, episode_len:13
# kl:0.01038,lr_multiplier:0.296,loss:2.0200886726379395,entropy:1.501114010810852,explained_var_old:0.378,explained_var_new:0.462
# batch i:479, episode_len:9
# kl:0.01364,lr_multiplier:0.296,loss:2.0474417209625244,entropy:1.5503644943237305,explained_var_old:0.402,explained_var_new:0.472
# batch i:480, episode_len:9
# kl:0.02382,lr_multiplier:0.296,loss:2.099008560180664,entropy:1.5480443239212036,explained_var_old:0.403,explained_var_new:0.470
# batch i:481, episode_len:9
# kl:0.01833,lr_multiplier:0.296,loss:2.0318031311035156,entropy:1.5182160139083862,explained_var_old:0.423,explained_var_new:0.479
# batch i:482, episode_len:11
# kl:0.03251,lr_multiplier:0.296,loss:2.077101945877075,entropy:1.552167296409607,explained_var_old:0.347,explained_var_new:0.456
# batch i:483, episode_len:11
# kl:0.01992,lr_multiplier:0.296,loss:2.0442702770233154,entropy:1.496468424797058,explained_var_old:0.399,explained_var_new:0.455
# batch i:484, episode_len:8
# kl:0.02307,lr_multiplier:0.296,loss:1.9938504695892334,entropy:1.5414596796035767,explained_var_old:0.466,explained_var_new:0.529
# batch i:485, episode_len:7
# kl:0.01345,lr_multiplier:0.296,loss:1.9428150653839111,entropy:1.506287693977356,explained_var_old:0.471,explained_var_new:0.551
# batch i:486, episode_len:7
# kl:0.02202,lr_multiplier:0.296,loss:2.052452325820923,entropy:1.498064398765564,explained_var_old:0.406,explained_var_new:0.460
# batch i:487, episode_len:8
# kl:0.01799,lr_multiplier:0.296,loss:2.1039280891418457,entropy:1.5556068420410156,explained_var_old:0.404,explained_var_new:0.459
# batch i:488, episode_len:14
# kl:0.02238,lr_multiplier:0.296,loss:2.0495901107788086,entropy:1.5477769374847412,explained_var_old:0.421,explained_var_new:0.515
# batch i:489, episode_len:8
# kl:0.02190,lr_multiplier:0.296,loss:1.941436529159546,entropy:1.4808189868927002,explained_var_old:0.461,explained_var_new:0.531
# batch i:490, episode_len:9
# kl:0.02903,lr_multiplier:0.296,loss:1.998406171798706,entropy:1.4924085140228271,explained_var_old:0.417,explained_var_new:0.503
# batch i:491, episode_len:12
# kl:0.02193,lr_multiplier:0.296,loss:2.1138463020324707,entropy:1.584223985671997,explained_var_old:0.426,explained_var_new:0.467
# batch i:492, episode_len:7
# kl:0.01887,lr_multiplier:0.296,loss:2.0882391929626465,entropy:1.5865890979766846,explained_var_old:0.428,explained_var_new:0.483
# batch i:493, episode_len:12
# kl:0.02533,lr_multiplier:0.296,loss:2.1217260360717773,entropy:1.5200908184051514,explained_var_old:0.361,explained_var_new:0.426
# batch i:494, episode_len:7
# kl:0.02794,lr_multiplier:0.296,loss:2.0752177238464355,entropy:1.521111011505127,explained_var_old:0.358,explained_var_new:0.433
# batch i:495, episode_len:11
# kl:0.02126,lr_multiplier:0.296,loss:2.0539660453796387,entropy:1.5120625495910645,explained_var_old:0.407,explained_var_new:0.471
# batch i:496, episode_len:7
# kl:0.02521,lr_multiplier:0.296,loss:2.1361489295959473,entropy:1.5745265483856201,explained_var_old:0.364,explained_var_new:0.415
# batch i:497, episode_len:10
# kl:0.03376,lr_multiplier:0.296,loss:2.1180365085601807,entropy:1.5704760551452637,explained_var_old:0.389,explained_var_new:0.457
# batch i:498, episode_len:14
# kl:0.01965,lr_multiplier:0.296,loss:1.9816758632659912,entropy:1.516312837600708,explained_var_old:0.419,explained_var_new:0.491
# batch i:499, episode_len:7
# kl:0.01427,lr_multiplier:0.296,loss:2.155869960784912,entropy:1.6155134439468384,explained_var_old:0.414,explained_var_new:0.489
# batch i:500, episode_len:10
# kl:0.02621,lr_multiplier:0.296,loss:1.9230101108551025,entropy:1.4749481678009033,explained_var_old:0.472,explained_var_new:0.533
# current self-play batch: 500
# num_playouts:2000, win: 6, lose: 4, tie:0
