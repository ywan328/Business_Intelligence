# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import time
## 模型预测的
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

## 数据降维处理的
from sklearn.decomposition import PCA,FastICA,FactorAnalysis,SparsePCA

##from lightgbm.sklearn import LGBMRegressor
from xgboost.sklearn import XGBRegressor

## 参数搜索和评价的
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV,cross_val_score,StratifiedKFold,train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#导入数据
Train_data = pd.read_csv("./train.csv", sep=' ')
Test_data = pd.read_csv("./test.csv", sep=' ')

# %%
# 合并方便后面的操作
df = pd.concat([Train_data, Test_data], ignore_index=True)

# %%
#查看数据信息
df.info()
#查看缺失值
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 31 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SaleID             200000 non-null  int64
#  1   name               200000 non-null  int64
#  2   regDate            200000 non-null  int64
#  3   model              199999 non-null  float64
#  4   brand              200000 non-null  int64
#  5   bodyType           193990 non-null  float64
#  6   fuelType           188396 non-null  float64
#  7   gearbox            192051 non-null  float64
#  8   power              200000 non-null  int64
#  9   kilometer          200000 non-null  float64
#  10  notRepairedDamage  200000 non-null  object
#  11  regionCode         200000 non-null  int64
#  12  seller             200000 non-null  int64
#  13  offerType          200000 non-null  int64
#  14  creatDate          200000 non-null  int64
#  15  price              150000 non-null  float64
#  16  v_0                200000 non-null  float64
#  17  v_1                200000 non-null  float64
#  18  v_2                200000 non-null  float64
#  19  v_3                200000 non-null  float64
#  20  v_4                200000 non-null  float64
#  21  v_5                200000 non-null  float64
#  22  v_6                200000 non-null  float64
#  23  v_7                200000 non-null  float64
#  24  v_8                200000 non-null  float64
#  25  v_9                200000 non-null  float64
#  26  v_10               200000 non-null  float64
#  27  v_11               200000 non-null  float64
#  28  v_12               200000 non-null  float64
#  29  v_13               200000 non-null  float64
#  30  v_14               200000 non-null  float64
# dtypes: float64(21), int64(9), object(1)
# memory usage: 47.3+ MB
# SaleID                   0
# name                     0
# regDate                  0
# model                    1
# brand                    0
# bodyType              6010
# fuelType             11604
# gearbox               7949
# power                    0
# kilometer                0
# notRepairedDamage        0
# regionCode               0
# seller                   0
# offerType                0
# creatDate                0
# price                50000
# v_0                      0
# v_1                      0
# v_2                      0
# v_3                      0
# v_4                      0
# v_5                      0
# v_6                      0
# v_7                      0
# v_8                      0
# v_9                      0
# v_10                     0
# v_11                     0
# v_12                     0
# v_13                     0
# v_14                     0
# dtype: int64

# %%
#类别特征nunique分布
cat_fea = ['name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
           'gearbox', 'kilometer', 'notRepairedDamage', 'regionCode',
           'seller', 'offerType', 'creatDate']
for fea in cat_fea:
    print(fea + "的特征分布如下：")
    print("{}特征有个{}不同的值".format(fea,df[fea].nunique()))
    print(df[fea].value_counts())
# Out:
# name的特征分布如下：
# name特征有个128660不同的值
# 387       376
# 55        373
# 708       367
# 1541      349
# 203       311
#          ...
# 13908       1
# 11863       1
# 30300       1
# 28255       1
# 151818      1
# Name: name, Length: 128660, dtype: int64
# regDate的特征分布如下：
# regDate特征有个3898不同的值
# 20000008    235
# 20000011    213
# 20000002    211
# 20000009    206
# 20000001    205
#            ...
# 20151212      1
# 19910909      1
# 19910801      1
# 20151209      1
# 19910807      1
# Name: regDate, Length: 3898, dtype: int64
# model的特征分布如下：
# model特征有个248不同的值
# 0.0      15534
# 19.0     12799
# 4.0      11235
# 1.0       8019
# 29.0      6964
#          ...
# 243.0        4
# 244.0        4
# 242.0        3
# 240.0        2
# 247.0        1
# Name: model, Length: 248, dtype: int64
# brand的特征分布如下：
# brand特征有个40不同的值
# 0     41953
# 4     22269
# 14    21434
# 10    18962
# 1     18421
# 6     13717
# 9      9666
# 5      6150
# 13     5203
# 11     3887
# 3      3281
# 7      3088
# 16     2993
# 25     2792
# 8      2785
# 27     2676
# 21     2090
# 15     1934
# 19     1861
# 20     1647
# 12     1508
# 22     1443
# 26     1294
# 30     1261
# 17     1225
# 24     1020
# 28      865
# 32      775
# 29      545
# 37      450
# 2       436
# 31      431
# 18      423
# 33      302
# 34      302
# 36      300
# 35      255
# 23      246
# 38       96
# 39       14
# Name: brand, dtype: int64
# bodyType的特征分布如下：
# bodyType特征有个8不同的值
# 0.0    55185
# 1.0    47232
# 2.0    40210
# 3.0    17982
# 4.0    12867
# 5.0    10101
# 6.0     8694
# 7.0     1719
# Name: bodyType, dtype: int64
# fuelType的特征分布如下：
# fuelType特征有个7不同的值
# 0.0    122145
# 1.0     62699
# 2.0      2948
# 3.0       340
# 4.0       149
# 5.0        63
# 6.0        52
# Name: fuelType, dtype: int64
# gearbox的特征分布如下：
# gearbox特征有个2不同的值
# 0.0    148754
# 1.0     43297
# Name: gearbox, dtype: int64
# kilometer的特征分布如下：
# kilometer特征有个13不同的值
# 15.0    129120
# 12.5     21035
# 10.0      8629
# 9.0       6941
# 8.0       6103
# 7.0       5469
# 6.0       4951
# 5.0       4254
# 4.0       3610
# 3.0       3339
# 2.0       3122
# 0.5       2441
# 1.0        986
# Name: kilometer, dtype: int64
# notRepairedDamage的特征分布如下：
# notRepairedDamage特征有个3不同的值
# 0.0    148585
# -       32393
# 1.0     19022
# Name: notRepairedDamage, dtype: int64
# regionCode的特征分布如下：
# regionCode特征有个8010不同的值
# 419     489
# 764     356
# 176     184
# 462     176
# 125     174
#        ...
# 7448      1
# 7670      1
# 8097      1
# 7662      1
# 4343      1
# Name: regionCode, Length: 8010, dtype: int64
# seller的特征分布如下：
# seller特征有个2不同的值
# 0    199999
# 1         1
# Name: seller, dtype: int64
# offerType的特征分布如下：
# offerType特征有个1不同的值
# 0    200000
# Name: offerType, dtype: int64
# creatDate的特征分布如下：
# creatDate特征有个106不同的值
# 20160403    7820
# 20160404    7563
# 20160320    7314
# 20160312    7205
# 20160321    7150
#             ...
# 20160213       1
# 20151117       1
# 20160108       1
# 20160106       1
# 20160115       1
# Name: creatDate, Length: 106, dtype: int64

# %%
#类别特征取值较少的，画出直方图,
#'notRepairedDamage'存在无效字符，'seller,offerType'数值分布极不平衡
plt.figure()
plt.figure(figsize=(16, 6))
i = 1
for fea in cat_fea:
    if df[fea].nunique()<50:
        plt.subplot(2, 4, i)
        i += 1
        v = df[fea].value_counts()
        fig = sns.barplot(x=v.index, y=v.values)
        for item in fig.get_xticklabels():
            item.set_rotation(90)
        plt.title(fea)
plt.tight_layout()
plt.show()

# %%
#'price'为长尾分布，需要做数据转换
plt.figure()
plt.figure(figsize=(10, 3))
plt.subplot(1, 2,1)
sns.distplot(Train_data['price'])
plt.subplot(1,2,2)
Train_data['price'].plot.box()
plt.tight_layout()

# %%
#'price'转化后的分布
plt.figure()
sns.distplot(np.log1p(Train_data['price']))

# %%
#数值特征分布，'power'的分布比较奇怪，后面做处理
num_fea = ['power', 'kilometer','price','v_0', 'v_1', 'v_2', 'v_3',
       'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
       'v_13', 'v_14']

f = pd.melt(Train_data, value_vars=num_fea)
g = sns.FacetGrid(f, col="variable",  col_wrap=3, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
#选取类别特征取值较少的，观察它们与价格的均值分布，其中'kilometer'对价格的影响很明显
plt.figure()
plt.figure(figsize=(20, 18))
i = 1
for f in cat_fea:
    if df[f].nunique() <= 50:
        plt.subplot(5, 3, i)
        i += 1
        v = df[~df['price'].isnull()].groupby(f,as_index=False)['price'].agg({f + '_price_mean': 'mean'}).reset_index()
        fig = sns.barplot(x=f, y=f + '_price_mean', data=v)
        for item in fig.get_xticklabels():
            item.set_rotation(90)
plt.tight_layout()
plt.show()

# %%
#匿名特征v_0,v_3,v_8,v_12与'price'相关性很高
corr1 = abs(df[df['price'].notnull()][num_fea].corr())
plt.figure(figsize=(10, 10))
sns.heatmap(corr1, linewidths=0.1, cmap=sns.cm.rocket_r)

# %% [markdown]
# ### 数据预处理

# %%
#'name'有部分重复值，做一个简单统计
df['name_count'] = df.groupby(['name'])['SaleID'].transform('count')
del df['name']
del df['offerType']
del df['seller']

#对'price'做对数变换
df['price'] = np.log1p(df['price'])

# %%
#用众数填充缺失值
df['fuelType'] = df['fuelType'].fillna(0)
df['gearbox'] = df['gearbox'].fillna(0)
df['bodyType'] = df['bodyType'].fillna(0)
df['model'] = df['model'].fillna(0)

# %%
#处理异常值
df['power'] = df['power'].map(lambda x: 600 if x>600 else x)#赛题限定power<=600
df['notRepairedDamage'] = df['notRepairedDamage'].astype('str').apply(lambda x: x if x != '-' else None).astype('float32')

# %%
# 对可分类的连续特征进行分桶，kilometer是已经分桶了
bin = [i*10 for i in range(31)]
df['power_bin'] = pd.cut(df['power'], bin, labels=False)

bin = [i*10 for i in range(24)]
df['model_bin'] = pd.cut(df['model'], bin, labels=False)

# %% [markdown]
# ### 特征工程

# %%
#时间提取出年，月，日和使用时间
from datetime import datetime
def date_process(x):
    year = int(str(x)[:4])
    month = int(str(x)[4:6])
    day = int(str(x)[6:8])

    if month < 1:
        month = 1

    date = datetime(year, month, day)
    return date

df['regDate'] = df['regDate'].apply(date_process)
df['creatDate'] = df['creatDate'].apply(date_process)
df['regDate_year'] = df['regDate'].dt.year
df['regDate_month'] = df['regDate'].dt.month
df['regDate_day'] = df['regDate'].dt.day
df['creatDate_year'] = df['creatDate'].dt.year
df['creatDate_month'] = df['creatDate'].dt.month
df['creatDate_day'] = df['creatDate'].dt.day
df['car_age_day'] = (df['creatDate'] - df['regDate']).dt.days#二手车使用天数
df['car_age_year'] = round(df['car_age_day'] / 365, 1)#二手车使用年数

# %% [markdown]
# #### 类别特征'model', 'brand', 'bodyType', 'fuelType','gearbox', 'kilometer', 'notRepairedDamage', 'regionCode',和数值特征'price','power','car_age_day'的交叉统计 只保留了部分有效组合。

# %%
#类别特征对价格的统计最大，最小，平均值等等
cat_cols = ['brand','model','kilometer','fuelType','bodyType']
for col in cat_cols:
    t = Train_data.groupby(col,as_index=False)['price'].agg(
        {col+'_count':'count',col+'_price_max':'max',col+'_price_median':'median',
         col+'_price_min':'min',col+'_price_sum':'sum',col+'_price_std':'std',col+'_price_mean':'mean'})
    df = pd.merge(df,t,on=col,how='left')

#行驶路程与功率统计
kk = ['kilometer','power']
t1 = Train_data.groupby(kk[0],as_index=False)[kk[1]].agg(
        {kk[0]+'_'+kk[1]+'_count':'count',kk[0]+'_'+kk[1]+'_max':'max',kk[0]+'_'+kk[1]+'_median':'median',
         kk[0]+'_'+kk[1]+'_min':'min',kk[0]+'_'+kk[1]+'_sum':'sum',kk[0]+'_'+kk[1]+'_std':'std',kk[0]+'_'+kk[1]+'_mean':'mean'})
df = pd.merge(df,t1,on=kk[0],how='left')

# %% [markdown]
# #### 由前面数据探索的结果可知部分v_0,v_3,v_8,v_12与price的相关性很高，所以做一些简单组合，发现效果不错

# %%
num_cols = [0,3,8,12]
for i in num_cols:
    for j in num_cols:
        df['new'+str(i)+'*'+str(j)]=df['v_'+str(i)]*df['v_'+str(j)]
        
for i in num_cols:
    for j in num_cols:
        df['new'+str(i)+'+'+str(j)]=df['v_'+str(i)]+df['v_'+str(j)]

for i in num_cols:
    for j in num_cols:
        df['new'+str(i)+'-'+str(j)]=df['v_'+str(i)]-df['v_'+str(j)]

for i in range(15):
    df['new'+str(i)+'*year']=df['v_'+str(i)] * df['car_age_year']

# %% [markdown]
# ### 建模

# %%
#划分训练数据和测试数据
df1 = df.copy()
test = df1[df1['price'].isnull()]
X_train = df1[df1['price'].notnull()].drop(['price','regDate','creatDate','SaleID','regionCode'],axis=1)
Y_train = df1[df1['price'].notnull()]['price']
X_test = df1[df1['price'].isnull()].drop(['price','regDate','creatDate','SaleID','regionCode'],axis=1)

# %%
cols = list(X_train)
oof = np.zeros(X_train.shape[0])
sub = test[['SaleID']].copy()
sub['price'] = 0
feat_df = pd.DataFrame({'feat': cols, 'imp': 0})
skf = KFold(n_splits=10, shuffle=True, random_state=2020)

# clf = XGBRegressor(
#     n_estimators=10000,
#     learning_rate=0.02,
#     boosting_type= 'gbdt',
#     objective = 'regression_l1',
#     max_depth = -1,
#     num_leaves=31,
#     min_child_samples = 20,
#     feature_fraction = 0.8,
#     bagging_freq = 1,
#     bagging_fraction = 0.8,
#     lambda_l2 = 2,
#     random_state=2020,
#     metric='mae'
# )

clf =XGBRegressor(max_depth=10, learning_rate=0.1, n_estimators=10000, reg_alpha=0.005, subsample=0.8,
                             gamma=0,colsample_bylevel=0.8, objective ='reg:squarederror')


mae = 0
for i, (trn_idx, val_idx) in enumerate(skf.split(X_train, Y_train)):
    print('--------------------- {} fold ---------------------'.format(i+1))
    trn_x, trn_y = X_train.iloc[trn_idx].reset_index(drop=True), Y_train[trn_idx]
    val_x, val_y = X_train.iloc[val_idx].reset_index(drop=True), Y_train[val_idx]
    clf.fit(
        trn_x, trn_y,
        eval_set=[(val_x, val_y)],
        eval_metric='mae',
        early_stopping_rounds=300,
        verbose=300
    )
    
    sub['price'] += np.expm1(clf.predict(X_test)) / skf.n_splits
    oof[val_idx] = clf.predict(val_x)
    print('val mae:', mean_absolute_error(np.expm1(val_y), np.expm1(oof[val_idx])))
    mae += mean_absolute_error(np.expm1(val_y), np.expm1(oof[val_idx]))/skf.n_splits

print('cv mae:', mae)
#生成提交文件
sub.to_csv("./submit-xgb.csv",index=False)
# Out:
# --------------------- 1 fold ---------------------
# [0]	validation_0-mae:6.77085
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11795
# [600]	validation_0-mae:0.11643
# [900]	validation_0-mae:0.11560
# [1200]	validation_0-mae:0.11497
# [1500]	validation_0-mae:0.11458
# [1800]	validation_0-mae:0.11438
# [2100]	validation_0-mae:0.11427
# [2400]	validation_0-mae:0.11418
# [2700]	validation_0-mae:0.11412
# [3000]	validation_0-mae:0.11408
# [3300]	validation_0-mae:0.11406
# [3600]	validation_0-mae:0.11405
# [3900]	validation_0-mae:0.11403
# [4200]	validation_0-mae:0.11403
# [4500]	validation_0-mae:0.11402
# [4800]	validation_0-mae:0.11402
# Stopping. Best iteration:
# [4640]	validation_0-mae:0.11402
#
# val mae: 482.7583552412062
# --------------------- 2 fold ---------------------
# [0]	validation_0-mae:6.78469
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11717
# [600]	validation_0-mae:0.11544
# [900]	validation_0-mae:0.11457
# [1200]	validation_0-mae:0.11405
# [1500]	validation_0-mae:0.11371
# [1800]	validation_0-mae:0.11353
# [2100]	validation_0-mae:0.11339
# [2400]	validation_0-mae:0.11330
# [2700]	validation_0-mae:0.11326
# [3000]	validation_0-mae:0.11322
# [3300]	validation_0-mae:0.11320
# [3600]	validation_0-mae:0.11318
# [3900]	validation_0-mae:0.11317
# Stopping. Best iteration:
# [3843]	validation_0-mae:0.11317
#
# val mae: 483.2132091194734
# --------------------- 3 fold ---------------------
# [0]	validation_0-mae:6.76990
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11589
# [600]	validation_0-mae:0.11412
# [900]	validation_0-mae:0.11332
# [1200]	validation_0-mae:0.11277
# [1500]	validation_0-mae:0.11246
# [1800]	validation_0-mae:0.11224
# [2100]	validation_0-mae:0.11210
# [2400]	validation_0-mae:0.11202
# [2700]	validation_0-mae:0.11196
# [3000]	validation_0-mae:0.11192
# [3300]	validation_0-mae:0.11188
# [3600]	validation_0-mae:0.11187
# [3900]	validation_0-mae:0.11185
# [4200]	validation_0-mae:0.11185
# [4500]	validation_0-mae:0.11185
# [4800]	validation_0-mae:0.11184
# [5100]	validation_0-mae:0.11182
# [5400]	validation_0-mae:0.11183
# Stopping. Best iteration:
# [5249]	validation_0-mae:0.11182
#
# val mae: 467.7922229863404
# --------------------- 4 fold ---------------------
# [0]	validation_0-mae:6.77912
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11815
# [600]	validation_0-mae:0.11606
# [900]	validation_0-mae:0.11531
# [1200]	validation_0-mae:0.11488
# [1500]	validation_0-mae:0.11452
# [1800]	validation_0-mae:0.11425
# [2100]	validation_0-mae:0.11410
# [2400]	validation_0-mae:0.11401
# [2700]	validation_0-mae:0.11394
# [3000]	validation_0-mae:0.11389
# [3300]	validation_0-mae:0.11386
# [3600]	validation_0-mae:0.11383
# [3900]	validation_0-mae:0.11382
# [4200]	validation_0-mae:0.11381
# [4500]	validation_0-mae:0.11380
# [4800]	validation_0-mae:0.11380
# [5100]	validation_0-mae:0.11380
# [5400]	validation_0-mae:0.11379
# Stopping. Best iteration:
# [5173]	validation_0-mae:0.11379
#
# val mae: 477.98279138853746
# --------------------- 5 fold ---------------------
# [0]	validation_0-mae:6.79728
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11762
# [600]	validation_0-mae:0.11596
# [900]	validation_0-mae:0.11512
# [1200]	validation_0-mae:0.11468
# [1500]	validation_0-mae:0.11433
# [1800]	validation_0-mae:0.11413
# [2100]	validation_0-mae:0.11399
# [2400]	validation_0-mae:0.11390
# [2700]	validation_0-mae:0.11384
# [3000]	validation_0-mae:0.11380
# [3300]	validation_0-mae:0.11378
# [3600]	validation_0-mae:0.11375
# [3900]	validation_0-mae:0.11374
# [4200]	validation_0-mae:0.11373
# [4500]	validation_0-mae:0.11372
# [4800]	validation_0-mae:0.11371
# [5100]	validation_0-mae:0.11371
# Stopping. Best iteration:
# [5059]	validation_0-mae:0.11371
#
# val mae: 493.27370399891305
# --------------------- 6 fold ---------------------
# [0]	validation_0-mae:6.78626
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11506
# [600]	validation_0-mae:0.11331
# [900]	validation_0-mae:0.11234
# [1200]	validation_0-mae:0.11174
# [1500]	validation_0-mae:0.11137
# [1800]	validation_0-mae:0.11116
# [2100]	validation_0-mae:0.11100
# [2400]	validation_0-mae:0.11090
# [2700]	validation_0-mae:0.11083
# [3000]	validation_0-mae:0.11079
# [3300]	validation_0-mae:0.11075
# [3600]	validation_0-mae:0.11072
# [3900]	validation_0-mae:0.11071
# [4200]	validation_0-mae:0.11070
# [4500]	validation_0-mae:0.11069
# [4800]	validation_0-mae:0.11069
# Stopping. Best iteration:
# [4640]	validation_0-mae:0.11068
#
# val mae: 473.3165263161547
# --------------------- 7 fold ---------------------
# [0]	validation_0-mae:6.78297
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11450
# [600]	validation_0-mae:0.11269
# [900]	validation_0-mae:0.11172
# [1200]	validation_0-mae:0.11120
# [1500]	validation_0-mae:0.11091
# [1800]	validation_0-mae:0.11066
# [2100]	validation_0-mae:0.11053
# [2400]	validation_0-mae:0.11040
# [2700]	validation_0-mae:0.11036
# [3000]	validation_0-mae:0.11032
# [3300]	validation_0-mae:0.11028
# [3600]	validation_0-mae:0.11027
# [3900]	validation_0-mae:0.11025
# [4200]	validation_0-mae:0.11024
# [4500]	validation_0-mae:0.11024
# [4800]	validation_0-mae:0.11023
# [5100]	validation_0-mae:0.11023
# Stopping. Best iteration:
# [5003]	validation_0-mae:0.11023
#
# val mae: 475.00069510264484
# --------------------- 8 fold ---------------------
# [0]	validation_0-mae:6.77603
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11875
# [600]	validation_0-mae:0.11709
# [900]	validation_0-mae:0.11635
# [1200]	validation_0-mae:0.11573
# [1500]	validation_0-mae:0.11550
# [1800]	validation_0-mae:0.11530
# [2100]	validation_0-mae:0.11517
# [2400]	validation_0-mae:0.11509
# [2700]	validation_0-mae:0.11505
# [3000]	validation_0-mae:0.11500
# [3300]	validation_0-mae:0.11498
# [3600]	validation_0-mae:0.11496
# [3900]	validation_0-mae:0.11494
# [4200]	validation_0-mae:0.11493
# Stopping. Best iteration:
# [4195]	validation_0-mae:0.11493
#
# val mae: 495.5315853986676
# --------------------- 9 fold ---------------------
# [0]	validation_0-mae:6.80093
# Will train until validation_0-mae hasn't improved in 300 rounds.
# [300]	validation_0-mae:0.11544
# [600]	validation_0-mae:0.11384
# [900]	validation_0-mae:0.11306
# [1200]	validation_0-mae:0.11254
# [1500]	validation_0-mae:0.11219
# [1800]	validation_0-mae:0.11195
# [2100]	validation_0-mae:0.11184
# [2400]	validation_0-mae:0.11175
# [2700]	validation_0-mae:0.11170
# [3000]	validation_0-mae:0.11165
# [3300]	validation_0-mae:0.11162
# [3600]	validation_0-mae:0.11162
# [3900]	validation_0-mae:0.11160
# [4200]	validation_0-mae:0.11159
